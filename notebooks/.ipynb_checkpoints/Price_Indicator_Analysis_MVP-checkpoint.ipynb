# %% [markdown]
# # Price_Indicator_Analysis_MVP

# %% [markdown]
# Analysis of common technical analysis indicators on daily price data for different products.

# %% [markdown]
# ## Data Collection

# %%
import pandas as pd
import numpy as np

import requests
import json
import quandl

import datetime

import matplotlib.pyplot as plt
import seaborn as sns

import sqlite3

import re

% matplotlib inline
sns.set_style('whitegrid')
blues = sns.color_palette('Blues')

# %% [markdown]
# The first step will be to get data from the [quandl API](https://www.quandl.com/collections/futures).  For this we use an api key generated from signing up for a free quandl account.
#
# We create a list of the symbols for the products we are interested in, which can be found by looking at the [documentation](https://docs.quandl.com/).
#
# Then loop through the products, read the price data into a dataframe, and attach the symbol:dataframe key:value pair to a dictionary object, after selecting the specific information we need.

# %%
# Get data from Quandl with api key
api_key = 'Hv95pPh1xQWzt5DFhxS7'

# Create list of symbols for the products we want data for
prod_list = ['CL', 'HO', 'NG', 'GC',
             'SI', 'AD', 'CD', 'EC',
             'BP', 'JY', 'US', 'C',
             'W', 'S', 'ES']

# Create a dict with keys as symbols and values as dataframe of price info
prod_dict = {}

# Iterate through list of prods and add data to dict
for prod in prod_list:
    # Quandl API call
    df = quandl.get('SCF/CME_{p}1_FW'.format(p=prod), authtoken=api_key)
    
    # Drop open interest column and rename Settle column
    df.drop(['Prev. Day Open Interest'], axis=1, inplace=True)
    df.rename(columns={'Open': 'open',
                      'High': 'high',
                      'Low': 'low',
                      'Settle': 'close',
                      'Volume': 'volume'}, inplace=True)
    # Add prod to dict
    prod_dict[prod] = df

# %% [markdown]
# Here is some summary information of the Crude Oil ('CL') dataframe

# %%
cl = prod_dict['CL']
cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2005-01-03 to 2014-12-31
# Data columns (total 5 columns):
# open      2517 non-null float64
# high      2517 non-null float64
# low       2517 non-null float64
# close     2517 non-null float64
# volume    2517 non-null float64
# dtypes: float64(5)
# memory usage: 118.0 KB

# %%
cl.describe().T
# Out:
#          count           mean           std    min        25%        50%  \
# open    2517.0      81.796207     19.832869  34.36      65.68      82.55
# high    2517.0      82.893532     19.961713  36.25      66.56      83.72
# low     2517.0      80.582003     19.695067  33.55      64.65      81.25
# close   2517.0      81.779758     19.855341  33.98      65.82      82.55
# volume  2517.0  241235.096146  96750.320207  50.00  175510.60  242868.00
#
#               75%        max
# open        96.90     145.19
# high        97.82     147.27
# low         95.56     143.22
# close       96.92     145.29
# volume  301777.00  670082.00

# %%
cl.head()
# Out:
#              open   high    low  close    volume
# Date
# 2005-01-03  43.10  43.10  41.25  42.12   69484.0
# 2005-01-04  42.18  44.13  41.85  43.91  100665.0
# 2005-01-05  43.90  44.00  42.60  43.39   91011.0
# 2005-01-06  43.39  45.75  42.80  45.56  122411.0
# 2005-01-07  45.50  46.10  44.75  45.43   99725.0

# %% [markdown]
# Now we have the data from quandl broken down into specific products and we have the columns we are interested in as well as a datetime object as an index.  Next we will do the same thing with the data from the [Cryptocompare API](https://www.cryptocompare.com/api/).

# %% [markdown]
# First step here will be do define the url and parameters we need.  This information can be gathered by reading through the documentation.
#
# Again we need to create a list of symbol names to use as arguments when calling the API.
#
# Then we do a `get` request using the `requests` library, loop through the symbols list and do some manipulation to the final dataframe.
#
# When this is all done we can just append the df to our prod_dict to put them all together.

# %%
# Cryptocompare API url
url = 'https://min-api.cryptocompare.com/data/histoday'

# List of cryptocurrencies to gather data for
symbol_list = ['BTC', 'ETH', 'XRP', 'LTC', 'XLM',
               'EOS', 'NEO', 'ADA', 'BCH', 'XMR']

# Iterate through the list to create a df for each symbol
for symbol in symbol_list:
    # Set relevant parameters, currency in USD and limit of 2000 data points
    params = {'fsym': symbol, 'tsym': 'USD', 'limit': 2000}
    
    # Call API and put data into a dataframe
    response = requests.get(url, params=params)
    data = response.json()['Data']
    df = pd.DataFrame(data)
    
    # Add date column and set to index
    df['Date'] = [datetime.date.fromtimestamp(d) for d in df.time]
    df = df[['open', 'high', 'low', 'close', 'volumeto', 'Date']]
    df.set_index('Date', inplace=True)
    
    # Rename volumeto column
    df.rename(columns={'volumeto': 'volume'}, inplace=True)
    
    # Append to prod_dict
    prod_dict[symbol] = df

# %% [markdown]
# Now all the products we are interested in are in the dictionary.

# %%
prod_dict.keys()
# Out:
# dict_keys(['CL', 'HO', 'NG', 'GC', 'SI', 'AD', 'CD', 'EC', 'BP', 'JY', 'US', 'C', 'W', 'S', 'ES', 'BTC', 'ETH', 'XRP', 'LTC', 'XLM', 'EOS', 'NEO', 'ADA', 'BCH', 'XMR'])

# %% [markdown]
# And just like before we can take a look at one of the new products to see that the information is in the same format.  Lets look at Bitcoin.

# %%
btc = prod_dict['BTC']
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2001 entries, 2012-10-09 to 2018-04-01
# Data columns (total 5 columns):
# open      2001 non-null float64
# high      2001 non-null float64
# low       2001 non-null float64
# close     2001 non-null float64
# volume    2001 non-null float64
# dtypes: float64(5)
# memory usage: 93.8+ KB

# %%
btc.describe().T
# Out:
#          count          mean           std        min         25%  \
# open    2001.0  1.487164e+03  2.991797e+03      10.17      235.83
# high    2001.0  1.547409e+03  3.131154e+03      10.65      240.01
# low     2001.0  1.416433e+03  2.809985e+03       9.74      231.78
# close   2001.0  1.490659e+03  2.994143e+03      10.17      235.85
# volume  2001.0  1.692008e+08  4.810454e+08  109479.89  3945871.12
#
#                 50%          75%           max
# open         442.66       894.16  1.934660e+04
# high         453.37       920.26  1.987062e+04
# low          431.10       848.32  1.875091e+04
# close        443.18       894.41  1.934549e+04
# volume  15315755.66  47619189.45  6.245732e+09

# %%
btc.head()
# Out:
#              open   high    low  close     volume
# Date
# 2012-10-09  11.90  12.19  11.77  12.12  333351.59
# 2012-10-10  12.12  12.15  11.86  12.03  238483.07
# 2012-10-11  12.03  12.15  11.92  12.00  259522.53
# 2012-10-12  12.00  12.11  11.85  11.86  141870.31
# 2012-10-13  11.86  12.03  11.50  11.74  271135.83

# %% [markdown]
# With all the data now collected and stored in a dictionary we want to create a SQL schema to store the data locally.  I chose to use a **3 table schema** with one table, **Data**, keeping track of my data sources, **Symbols** housing all the product symbols with some product specific information, and finally **Daily_Prices** which holds all the daily price and volume information.
#
# The **Symbols** table links to the **Data** table on an id and the **Daily_Prices** table links to the **Symbols** table on the symbol name.

# %% [markdown]
# Here is the creation of the three tables, starting with **Data**

# %%
# SQLite file name to store database
sqlite_file = 'securities_master_db.sqlite'

# DATA TABLE
table_name = 'Data'
id_col = 'id'
name_col = 'name'
url_col = 'url'
dtype_int = 'INTEGER'
dtype_text = 'TEXT'

# Connect to the database file
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Create a new table with 3 columns
c.execute('CREATE TABLE {tn} ({ic} {dti} PRIMARY KEY, {nc} {dtt}, {uc} {dtt})'\
          .format(tn=table_name, ic=id_col, dti=dtype_int, nc=name_col, dtt=dtype_text, uc=url_col))

# Commit changes and close
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-1a65be4edf8c> in <module>()
#      15
#      16 # Create a new table with 3 columns
# ---> 17 c.execute('CREATE TABLE {tn} ({ic} {dti} PRIMARY KEY, {nc} {dtt}, {uc} {dtt})'          .format(tn=table_name, ic=id_col, dti=dtype_int, nc=name_col, dtt=dtype_text, uc=url_col))
#      18
#      19 # Commit changes and close
#
# OperationalError: table Data already exists

# %% [markdown]
# With the table created, I chose to manually add the data sources since there are only three.

# %%
# Connect to database file
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Add value for Cryptocompare to Data table
c.execute("INSERT INTO {tn} ({ic}, {nc}, {uc}) VALUES (1, 'Cryptocompare', 'https://min-api.cryptocompare.com')"\
          .format(tn=table_name, ic=id_col, nc=name_col, uc=url_col))

# Add value for Quandl to Data table
c.execute("INSERT INTO {tn} ({ic}, {nc}, {uc}) VALUES (2, 'Quandl', 'https://docs.quandl.com')"\
          .format(tn=table_name, ic=id_col, nc=name_col, uc=url_col))

# Add value for Quantopian to Data table
c.execute("INSERT INTO {tn} ({ic}, {nc}, {uc}) VALUES (3, 'Quantopian', 'https://www.quantopian.com/data')"\
          .format(tn=table_name, ic=id_col, nc=name_col, uc=url_col))

# Commit and close
conn.commit()
conn.close()

# %% [markdown]
# Now we will add the **Symbols** table

# %%
# SYMBOLS TABLE
# Initialize variables for file name, table, columns, data types
table_name = 'Symbols'

data_table = 'Data'
data_id = 'id'

id_col = 'id'
data_id_col = 'data_id'
symbol_col = 'symbol'
name_col = 'name'
sector_col = 'sector'
exchange_col = 'exchange'
dtype_int = 'INTEGER'
dtype_text = 'TEXT'

# Connect to the database file
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Create a new table with 3 columns
c.execute('CREATE TABLE {tn} ({ic} {dti} PRIMARY KEY,\
                              {dc} {dti},\
                              {sc} {dtt},\
                              {nc} {dtt},\
                              {sec} {dtt},\
                              {ec} {dtt},\
                              FOREIGN KEY ({dc}) REFERENCES {dt} ({dic}))'\
         .format(tn=table_name, ic=id_col, dti=dtype_int, dc=data_id_col, sc=symbol_col,\
                 dtt=dtype_text, nc=name_col, sec=sector_col, ec=exchange_col,\
                 dt=data_table, dic=data_id))

# Commit changes and close
conn.commit()
conn.close()

# %% [markdown]
# Now that we have the **Symbols** table we can insert the information.  I chose to add some information about each product that I thought would be interesting for later analysis.  The following dictionary maps all the *products* to a `list` of information about that product including *data source, name, sector, exchange*.

# %%
# Dict of all products with maps to data_id, name, sector, and exchange
products = {'CL': [2, 'Crude', 'Energy', 'CME'],
            'HO': [2, 'HeatOil', 'Energy', 'CME'],
            'NG': [2, 'NatGas', 'Energy', 'CME'],
            'GC': [2, 'Gold', 'Metals', 'CME'],
            'SI': [2, 'Silver', 'Metals', 'CME'],
            'AD': [2, 'Aussie', 'Forex', 'CME'],
            'CD': [2, 'Canadien', 'Forex', 'CME'],
            'EC': [2, 'Euro', 'Forex', 'CME'],
            'BP': [2, 'Pound', 'Forex', 'CME'],
            'JY': [2, 'Yen', 'Forex', 'CME'],
            'US': [2, '30-yr', 'Treasuries', 'CME'],
            'C': [2, 'Corn', 'Grains', 'CME'],
            'W': [2, 'Wheat', 'Grains', 'CME'],
            'S': [2, 'Soybeans', 'Grains', 'CME'],
            'ES': [2, 'E-mini', 'Indexes', 'CME'],
            'BTC': [1, 'Bitcoin', 'Cryptocurrency', 'CCAgg'],
            'ETH': [1, 'Ethereum', 'Cryptocurrency', 'CCAgg'],
            'XRP': [1, 'Ripple', 'Cryptocurrency', 'CCAgg'],
            'BCH': [1, 'BitcoinCash', 'Cryptocurrency', 'CCAgg'],
            'LTC': [1, 'Litecoin', 'Cryptocurrency', 'CCAgg'],
            'ADA': [1, 'Cardano', 'Cryptocurrency', 'CCAgg'],
            'NEO': [1, 'Neo', 'Cryptocurrency', 'CCAgg'],
            'XLM': [1, 'Stellar', 'Cryptocurrency', 'CCAgg'],
            'EOS': [1, 'EOS', 'Cryptocurrency', 'CCAgg'],
            'XMR': [1, 'Monero', 'Cryptocurrency', 'CCAgg'],}

# %% [markdown]
# Here is the code to insert the information into the **Symbols** table

# %%
# Create the column name list for database insertion
table_name = 'Symbols'
cols = ['data_id', 'symbol', 'name', 'sector', 'exchange']

# Open a connection to the database
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Iterate through all symbols of product_dict
for symbol, s_info in products.items():
    # Set params and insert row into database
    params = (s_info[0], symbol, s_info[1], s_info[2], s_info[3])
    c.execute("INSERT INTO {tn} ({c0}, {c1}, {c2}, {c3}, {c4}) VALUES (?, ?, ?, ?, ?)"\
            .format(tn=table_name, c0=cols[0], c1=cols[1], c2=cols[2],\
            c3=cols[3], c4=cols[4]), params)
    
# Close connection to database
conn.commit()
conn.close()

# %% [markdown]
# And finally the **Daily_Prices** table

# %%
# DAILY_PRICES TABLE
# Initialize variables for file name, table, columns, data types
table_name = 'Daily_Prices'
symbols_table = 'Symbols'

id_col = 'id'
data_id_col = 'data_id'
symbol_col = 'symbol'
date_col = 'date'
open_col = 'open'
high_col = 'high'
low_col = 'low'
close_col = 'close'
volume_col = 'volume'

dtype_int = 'INTEGER'
dtype_text = 'TEXT'
dtype_real = 'REAL'

# Connect to the database file
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Create a new table with 3 columns
c.execute('CREATE TABLE {tn} ({ic} {dti} PRIMARY KEY,\
                              {dc} {dti},\
                              {sc} {dtt},\
                              {dtc} {dtt},\
                              {oc} {dtr},\
                              {hc} {dtr},\
                              {lc} {dtr},\
                              {cc} {dtr},\
                              {vc} {dti},\
                              FOREIGN KEY ({sc}) REFERENCES {st} ({sc}))'\
         .format(tn=table_name, ic=id_col, dti=dtype_int, dc=data_id_col, sc=symbol_col,\
                 dtt=dtype_text, dtc=date_col, oc=open_col, dtr=dtype_real, hc=high_col,\
                 lc=low_col, cc=close_col, vc=volume_col, st=symbols_table))

# Commit changes and close
conn.commit()
conn.close()

# %% [markdown]
# We will hold off on inserting the price data into the table right now because it needs to be cleaned first.  So lets move on to that part of the analysis.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# In examining the data a number of issues stuck out from the start.

# %% [markdown]
# First of all, regarding the cryptocurrency data, due to the fact that each asset began trading at a different time, but we collected 2,000 data points for each, there are a lot of **zero** values.
#
# To clean this up and also take a look at data from times where there was enough liquidity to actually trade, I decided to pick a start date for each set of cryptocurrency to be the first day that trading volume reached **$1,000,000 USD**.

# %%
# Use the cryptocurrency symbol list from before to iterate through the dict
for crypto, df in prod_dict.items():
    if crypto in symbol_list:
        # Find the first date that reached 1 million USD volume
        start_date = df.index[df.volume > 1000000].tolist()[0]
        
        # Filter the dataframe and reappend it to the dict
        df = df[start_date:]
        prod_dict[crypto] = df

# %% [markdown]
# To check that this worked compare the new `btc_clean` first rows with the old `btc` rows that started at `2012-10-08`

# %%
btc_clean = prod_dict['BTC']
btc_clean.head()
# Out:
#              open   high    low  close      volume
# Date
# 2012-10-25  10.86  10.95   9.74  10.17  1020616.67
# 2012-10-26  10.17  10.84   9.82  10.26   496747.54
# 2012-10-27  10.26  10.95  10.25  10.70   236640.50
# 2012-10-28  10.70  10.94  10.32  10.60   400173.50
# 2012-10-29  10.60  10.89  10.58  10.89   279843.08

# %% [markdown]
# The next thing I noticed that needed to be addressed was certain days where volume was unlikely to be reported correctly.  There were alot of zero and low number values, considering the goal was to only look at highly liquid products.  For example....

# %%
mean_vol = cl.volume.mean()
std_vol = cl.volume.std()

# %%
cl.volume[cl.volume < (mean_vol - (2.0 * std_vol))]
# Out:
# Date
# 2005-06-30     2349.0
# 2005-07-01     1069.0
# 2005-07-08      810.0
# 2005-12-23    37520.0
# 2006-09-04     4869.0
# 2009-07-10       50.0
# 2010-04-01     3536.0
# 2012-12-24    40380.0
# 2013-12-24    43473.0
# Name: volume, dtype: float64

# %% [markdown]
# This is likely due to poor data or something to do with the way they create the continuous contract, by taking weighting of the two current front months.  For this project **volume** is only going to be used in the case of a break-out strategy where we need to find days that are **200% of the rolling average volume**.  Thus, for our purposes taking these likely incorrect data and simply replacing them with the mean will suffice.

# %%
def Replace(x, mean, std):
    if x < (mean - (2 * std)):
        return mean
    else:
        return x

# %%
for prod, df in prod_dict.items():
    # Calculate mean and std for volumn column of dataframe
    mean_vol = df.volume.mean()
    std_vol = df.volume.std()
    
    # Apply lambda function to transform poor data
    df['volume'] = df['volume'].apply(lambda x: Replace(x, mean_vol, std_vol))
# Out:
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# Check to see this worked with our Crude Oil dataframe, which should now have no volume data that is more than 2 stds below the mean.

# %%
cl.volume[cl.volume < (mean_vol - (2.0 * std_vol))]
# Out:
# Series([], Name: volume, dtype: float64)

# %% [markdown]
# The last thing to do as far as cleaning the data before entering it into the database was to write a function that could check for outliers in price.  The fact is that these 3+ std moves do happen in commodity markets so my thought was to create a price chart and highlight the big outliers.
#
# By looking at the entire price chart it should be easy to tell if the outlier was because of faulty data or simply because the market had made a big move so price was seriously deviating from the overall long-term mean.

# %%
def check_outliers(df):
    ''' This function finds all closing price points that are more than 3 stds away from
        the mean and plots them on a line graph of all the data.  This can be used to see
        if these points are truly outliers.

        Args: df - dataframe to be checked for outliers

        Return: None - shows a graph of the price data series with annotations for outliers
    '''
    # Use a copy of the dataframe
    cpy = df.copy()
    # Create range of values that are more than 3 stds away from mean
    cpy['stds_from_mean'] = ((cpy['close'] - cpy['close'].mean()).apply(abs)) / cpy['close'].std()
    locs_gt_3std = [cpy.index.get_loc(x) for x in cpy.index[cpy['stds_from_mean'] > 3.0]]

    # Plot the price data, highlighting the outliers
    plt.figure(figsize=(14,7))
    plt.plot(cpy.index, cpy.close, linestyle='solid', markevery=locs_gt_3std,
                marker='o', markerfacecolor='r', label='Outliers')

    # Apply title, legend and labels
    plt.title('Closing Prices')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.grid()

    plt.show()

    # Print out description
    print('Number of data points: {}'.format(len(cpy.index)))
    print('Number of outliers: {}'.format(len(locs_gt_3std)))

# %% [markdown]
# So in sticking with the theme we will check the **Crude Oil** market as well as **Bitcoin** to see what kind of outliers we are looking at.

# %%
check_outliers(cl)
# Out:
# Number of data points: 2517
# Number of outliers: 6

# %%
check_outliers(btc)
# Out:
# Number of data points: 2001
# Number of outliers: 71

# %% [markdown]
# Each market has its outliers but they were due to the market itself making a strong move away from the mean value for the entire time series.  This is not uncommon for commodities and cryptocurrencies.
#
# In looking at the chart and having experience with these products I am comfortable saying that none of the points are far off due to inaccurate data.

# %% [markdown]
# At this point I am comfortable with the data and therefore can insert it into the database.  Then it will be time to move on to manipulation, by creating new columns for the indicators that I want to explore.

# %% [markdown]
# Here is the script for entering the data into the **Daily_Prices** table of the SQL database.

# %%
# Set table_name
table_name = 'Daily_Prices'

# Create the column name list for database insertion
cols = ['data_id', 'symbol', 'date', 'open', 'high', 'low', 'close', 'volume']

# Open a connection to the database
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# Iterate through all symbols and then the dataframe to get all price data
for symbol, df in prod_dict.items():
    data_id = products[symbol][0]
    
    for i, row in df.iterrows():
        date = i.strftime('%Y-%m-%d')
        # Set params and insert row into database
        params = (data_id, symbol, date, row.open, row.high, row.low, row.close, row.volume)
        c.execute("INSERT INTO {tn} ({c0}, {c1}, {c2}, {c3}, {c4}, {c5}, {c6}, {c7}) VALUES (?, ?, ?, ?, ?, ?, ?, ?)"\
            .format(tn=table_name, c0=cols[0], c1=cols[1], c2=cols[2], c3=cols[3], c4=cols[4],\
            c5=cols[5], c6=cols[6], c7=cols[7]), params)

# Close connection to database
conn.commit()
conn.close()

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# The next step in the analysis is to add columns to each product's dataframe to represent the specific indicators that we are interested in observing.  These can all be calculated from the current, **open, high, low, close, volume** data that we have.
#
# We also want to add columns that track future price changes.  I am choosing to look at a few different time frames, next day, 5 days out, 10 days out, and 20 days out.  Once we have columns for each indicator as a binary (0 if no signal, 1 if signal) and columns for the future returns from that point we can analyze which (if any) of the indicators shows promise for consistently predicting future returns.

# %% [markdown]
# Below is the code to add each column we need.  In the end, just passing a dataframe which is formatted as we have setup in the above analysis to the `add_all_indicators` function will do all the work.

# %%
def vol_bo(row, direction):
    ''' This is a helper function to use in volume breakout column creation.  It takes
        in a row of a dataframe and a direction of trade, and returns 1 if a breakout
        has occured, 0 if not.

        Args: row - row of a dataframe
              direction - 'long' or 'short'

        Return: 1 if volume breakout occured, 0 if not
    '''
    if row['volume'] > (2 * row['20day_ave_vol']):
        if (direction == 'long') and (row['close_gt_prev_h'] > 0.0):
            return 1
        elif (direction == 'short') and (row['close_lt_prev_l'] < 0.0):
            return 1
        else:
            return 0

def range_bo(row, direction):
    ''' This is a helper function to use in range breakout column creation.  It takes
        in a row of a dataframe and a direction of trade, and returns 1 if a breakout
        has occured, 0 if not.

        Args: row - row of a dataframe
              direction - 'long' or 'short'

        Return: 1 if volume breakout occured, 0 if not
    '''
    if direction == 'long':
        if row['high'] > row['20day_high']:
            return 1
        else:
            return 0
    if direction == 'short':
        if row['low'] < row['20day_low']:
            return 1
        else:
            return 0

def ma_signal(row, ma, direction):
    ''' This is a helper function to use in all moving average columns creation.  It takes
        in a row of a dataframe, a length of time and a direction of trade, and returns
        1 if a breakout has occured, 0 if not.

        Args: row - row of a dataframe
              ma - length of time for moving average
              direction - 'long' or 'short'

        Return: 1 if volume breakout occured, 0 if not
    '''
    if direction == 'long':
        if row['close'] > row['ma{}'.format(ma)]:
            return 1
        else:
            return 0
    if direction == 'short':
        if row['close'] < row['ma{}'.format(ma)]:
            return 1
        else:
            return 0

def bb_signal(row, direction):
    ''' This is a helper function to use in all bollinger band column creation.  It takes
        in a row of a dataframe and a direction of trade, and returns 1 if a breakout
        has occured, 0 if not.

        Args: row - row of a dataframe
              direction - 'long' or 'short'

        Return: 1 if volume breakout occured, 0 if not
    '''
    if direction == 'long':
        if row['low'] < row['bb_low']:
            return 1
        else:
            return 0
    if direction == 'short':
        if row['high'] > row['bb_high']:
            return 1
        else:
            return 0

def add_all_indicators(df):
    ''' This function takes in a cleaned dataframe of price information and uses
        the helper functions to add all relevant indicators as columns
        to the dataframe.

        Args: df - cleaned dataframe of price information

        Return: df - cleaned dataframe with added columns for all indicators
    '''
    # All columns for 20day volume breakout indicator
    df['20day_ave_vol'] = df.volume.rolling(window=20, center=False).mean().shift(1)
    df['close_gt_prev_h'] = df['close'] - df['high'].shift(1)
    df['close_lt_prev_l'] = df['close'] - df['low'].shift(1)
    df['vol_bo_long'] = df.apply(lambda row: vol_bo(row, direction='long'), axis=1)
    df['vol_bo_short'] = df.apply(lambda row: vol_bo(row, direction='short'), axis=1)
    df['vol_bo_long'].fillna(value=0, inplace=True)
    df['vol_bo_short'].fillna(value=0, inplace=True)

    # All columns for 20day range breakout indicator
    df['20day_high'] = df.high.rolling(window=20, center=False).max().shift(1)
    df['20day_low'] = df.low.rolling(window=20, center=False).min().shift(1)
    df['range_bo_long'] = df.apply(lambda row: range_bo(row, direction='long'), axis=1)
    df['range_bo_short'] = df.apply(lambda row: range_bo(row, direction='short'), axis=1)

    # All columns for moving average indicators
    df['ma20'] = df['close'].rolling(window=20, center=False).mean()
    df['ma50'] = df['close'].rolling(window=50, center=False).mean()
    df['ma100'] = df['close'].rolling(window=100, center=False).mean()
    df['ma20_long'] = df.apply(lambda row: ma_signal(row, ma=20, direction='long'), axis=1)
    df['ma20_short'] = df.apply(lambda row: ma_signal(row, ma=20, direction='short'), axis=1)
    df['ma50_long'] = df.apply(lambda row: ma_signal(row, ma=50, direction='long'), axis=1)
    df['ma50_short'] = df.apply(lambda row: ma_signal(row, ma=50, direction='short'), axis=1)
    df['ma100_long'] = df.apply(lambda row: ma_signal(row, ma=100, direction='long'), axis=1)
    df['ma100_short'] = df.apply(lambda row: ma_signal(row, ma=100, direction='short'), axis=1)

    # All columns for bollinger band indicators
    df['bb_high'] = df['ma20'] + (2 * df['close'].rolling(window=20, center=False).std())
    df['bb_low'] = df['ma20'] - (2 * df['close'].rolling(window=20, center=False).std())
    df['bb_long'] = df.apply(lambda row: bb_signal(row, direction='long'), axis=1)
    df['bb_short'] = df.apply(lambda row: bb_signal(row, direction='short'), axis=1)

    # All columns for percentage change for timeframe into the future
    df['pct_change_1day'] = df['close'].pct_change()
    df['pct_change_5day'] = df['close'].pct_change(periods=5)
    df['pct_change_10day'] = df['close'].pct_change(periods=10)
    df['pct_change_20day'] = df['close'].pct_change(periods=20)

    return df

# %% [markdown]
# Lets check out how it works for Crude Oil and Bitcoin

# %%
cl.head()
# Out:
#              open   high    low  close    volume
# Date
# 2005-01-03  43.10  43.10  41.25  42.12   69484.0
# 2005-01-04  42.18  44.13  41.85  43.91  100665.0
# 2005-01-05  43.90  44.00  42.60  43.39   91011.0
# 2005-01-06  43.39  45.75  42.80  45.56  122411.0
# 2005-01-07  45.50  46.10  44.75  45.43   99725.0

# %%
cl_indicators = add_all_indicators(cl)
cl_indicators.tail()
# Out:
#              open   high    low  close    volume  20day_ave_vol  \
# Date
# 2014-12-24  56.80  57.15  55.07  55.84  174969.0      358766.18
# 2014-12-26  55.86  56.59  54.51  54.73  138280.0      352792.28
# 2014-12-29  55.05  55.74  52.90  53.61  253089.0      346788.83
# 2014-12-30  53.72  54.32  52.70  54.12  230228.0      331802.13
# 2014-12-31  53.87  54.02  52.44  53.27  247510.0      317298.38
#
#             close_gt_prev_h  close_lt_prev_l  vol_bo_long  vol_bo_short  \
# Date
# 2014-12-24            -1.72             0.78          0.0           0.0
# 2014-12-26            -2.42            -0.34          0.0           0.0
# 2014-12-29            -2.98            -0.90          0.0           0.0
# 2014-12-30            -1.62             1.22          0.0           0.0
# 2014-12-31            -1.05             0.57          0.0           0.0
#
#                   ...         ma100_long  ma100_short    bb_high     bb_low  \
# Date              ...
# 2014-12-24        ...                  0            1  72.792675  50.138525
# 2014-12-26        ...                  0            1  70.647242  50.387958
# 2014-12-29        ...                  0            1  70.104360  49.676840
# 2014-12-30        ...                  0            1  68.713782  49.579418
# 2014-12-31        ...                  0            1  67.645476  49.286724
#
#             bb_long  bb_short  pct_change_1day  pct_change_5day  \
# Date
# 2014-12-24        0         0        -0.022409        -0.013393
# 2014-12-26        0         0        -0.019878         0.008662
# 2014-12-29        0         0        -0.020464        -0.059606
# 2014-12-30        0         0         0.009513        -0.020630
# 2014-12-31        0         0        -0.015706        -0.067402
#
#             pct_change_10day  pct_change_20day
# Date
# 2014-12-24         -0.083689         -0.246322
# 2014-12-26         -0.087073         -0.257294
# 2014-12-29         -0.072652         -0.189569
# 2014-12-30         -0.032016         -0.215652
# 2014-12-31         -0.048682         -0.203499
#
# [5 rows x 31 columns]

# %%
cl_indicators.describe().T
# Out:
#                    count           mean           std           min  \
# open              2517.0      81.796207     19.832869     34.360000
# high              2517.0      82.893532     19.961713     36.250000
# low               2517.0      80.582003     19.695067     33.550000
# close             2517.0      81.779758     19.855341     33.980000
# volume            2517.0  242044.416712  95788.999248  50742.000000
# 20day_ave_vol     2497.0  242391.874480  77703.758445  89659.910000
# close_gt_prev_h   2516.0      -1.109487      1.958492    -12.200000
# close_lt_prev_l   2516.0       1.202332      1.864001     -8.680000
# vol_bo_long       2517.0       0.000397      0.019932      0.000000
# vol_bo_short      2517.0       0.001589      0.039841      0.000000
# 20day_high        2497.0      87.243793     20.154008     43.600000
# 20day_low         2497.0      76.559785     19.037560     33.550000
# range_bo_long     2517.0       0.165276      0.371503      0.000000
# range_bo_short    2517.0       0.127135      0.333191      0.000000
# ma20              2498.0      82.014500     19.519478     39.171000
# ma50              2468.0      82.300608     19.024766     40.700320
# ma100             2418.0      82.613358     18.069201     44.466640
# ma20_long         2517.0       0.535558      0.498833      0.000000
# ma20_short        2517.0       0.456893      0.498237      0.000000
# ma50_long         2517.0       0.562972      0.496117      0.000000
# ma50_short        2517.0       0.417561      0.493255      0.000000
# ma100_long        2517.0       0.602304      0.489519      0.000000
# ma100_short       2517.0       0.358363      0.479615      0.000000
# bb_high           2498.0      87.285229     20.230603     43.875214
# bb_low            2498.0      76.743771     19.242258     32.782122
# bb_long           2517.0       0.112038      0.315476      0.000000
# bb_short          2517.0       0.102503      0.303369      0.000000
# pct_change_1day   2516.0       0.000329      0.021711     -0.122478
# pct_change_5day   2512.0       0.001530      0.047067     -0.250230
# pct_change_10day  2507.0       0.002899      0.064651     -0.273084
# pct_change_20day  2497.0       0.006359      0.094590     -0.399850
#
#                             25%            50%            75%            max
# open                  65.680000      82.550000      96.900000     145.190000
# high                  66.560000      83.720000      97.820000     147.270000
# low                   64.650000      81.250000      95.560000     143.220000
# close                 65.820000      82.550000      96.920000     145.290000
# volume            176838.400000  242868.000000  301777.000000  670082.000000
# 20day_ave_vol     213491.190000  249613.120000  293932.000000  436907.800000
# close_gt_prev_h       -2.040000      -0.856000       0.080000      10.160000
# close_lt_prev_l        0.159500       1.088000       2.230000      16.930000
# vol_bo_long            0.000000       0.000000       0.000000       1.000000
# vol_bo_short           0.000000       0.000000       0.000000       1.000000
# 20day_high            70.900000      88.630000     102.100000     147.270000
# 20day_low             60.750000      77.280000      91.520000     131.526000
# range_bo_long          0.000000       0.000000       0.000000       1.000000
# range_bo_short         0.000000       0.000000       0.000000       1.000000
# ma20                  65.649650      83.394350      96.262100     139.006100
# ma50                  65.845070      85.009600      96.676560     133.422480
# ma100                 66.882055      85.714890      97.443760     125.635680
# ma20_long              0.000000       1.000000       1.000000       1.000000
# ma20_short             0.000000       0.000000       1.000000       1.000000
# ma50_long              0.000000       1.000000       1.000000       1.000000
# ma50_short             0.000000       0.000000       1.000000       1.000000
# ma100_long             0.000000       1.000000       1.000000       1.000000
# ma100_short            0.000000       0.000000       1.000000       1.000000
# bb_high               70.720579      88.909002     101.817265     150.598864
# bb_low                60.888152      77.603871      91.821416     131.184941
# bb_long                0.000000       0.000000       0.000000       1.000000
# bb_short               0.000000       0.000000       0.000000       1.000000
# pct_change_1day       -0.011099       0.000810       0.011722       0.142711
# pct_change_5day       -0.024293       0.002992       0.028497       0.310891
# pct_change_10day      -0.033914       0.004162       0.041804       0.317245
# pct_change_20day      -0.048775       0.009374       0.066478       0.399584

# %% [markdown]
# And for Bitcoin

# %%
btc.head()
# Out:
#              open   high    low  close     volume
# Date
# 2012-10-09  11.90  12.19  11.77  12.12  333351.59
# 2012-10-10  12.12  12.15  11.86  12.03  238483.07
# 2012-10-11  12.03  12.15  11.92  12.00  259522.53
# 2012-10-12  12.00  12.11  11.85  11.86  141870.31
# 2012-10-13  11.86  12.03  11.50  11.74  271135.83

# %%
btc_indicators = add_all_indicators(btc)
btc.tail()
# Out:
#                open     high      low    close        volume  20day_ave_vol  \
# Date
# 2018-03-28  7959.78  7983.77  6927.11  7106.62  1.379180e+09   1.166837e+09
# 2018-03-29  7106.62  7280.27  6595.26  6853.76  1.584675e+09   1.131715e+09
# 2018-03-30  6853.75  7228.40  6806.34  6943.77  9.154006e+08   1.156703e+09
# 2018-03-31  6943.77  7056.22  6463.54  6835.84  8.898877e+08   1.133732e+09
# 2018-04-01  6835.58  6999.52  6792.30  6999.52  1.342822e+07   1.106456e+09
#
#             close_gt_prev_h  close_lt_prev_l  vol_bo_long  vol_bo_short  \
# Date
# 2018-03-28         -1011.17          -645.98          0.0           0.0
# 2018-03-29         -1130.01           -73.35          0.0           0.0
# 2018-03-30          -336.50           348.51          0.0           0.0
# 2018-03-31          -392.56            29.50          0.0           0.0
# 2018-04-01           -56.70           535.98          0.0           0.0
#
#                   ...         ma100_long  ma100_short      bb_high  \
# Date              ...
# 2018-03-28        ...                  0            1  9617.095099
# 2018-03-29        ...                  0            1  9722.010776
# 2018-03-30        ...                  0            1  9623.274823
# 2018-03-31        ...                  0            1  9580.595654
# 2018-04-01        ...                  0            1  9474.901335
#
#                  bb_low  bb_long  bb_short  pct_change_1day  pct_change_5day  \
# Date
# 2018-03-28  7350.457901        1         0        -0.107184        -0.168628
# 2018-03-29  7051.191224        1         0        -0.035581        -0.191091
# 2018-03-30  6889.820177        1         0         0.013133        -0.148234
# 2018-03-31  6701.868346        1         0        -0.015543        -0.124562
# 2018-04-01  6591.502665        0         0         0.023944        -0.120639
#
#             pct_change_10day  pct_change_20day
# Date
# 2018-03-28         -0.175866         -0.231946
# 2018-03-29         -0.231702         -0.220922
# 2018-03-30         -0.220795         -0.272511
# 2018-03-31         -0.216521         -0.252272
# 2018-04-01         -0.216600         -0.235870
#
# [5 rows x 31 columns]

# %%
btc_indicators.describe().T
# Out:
#                    count          mean           std            min  \
# open              2001.0  1.487164e+03  2.991797e+03      10.170000
# high              2001.0  1.547409e+03  3.131154e+03      10.650000
# low               2001.0  1.416433e+03  2.809985e+03       9.740000
# close             2001.0  1.490659e+03  2.994143e+03      10.170000
# volume            2001.0  1.692008e+08  4.810454e+08  109479.890000
# 20day_ave_vol     1981.0  1.658894e+08  4.370941e+08  268276.273500
# close_gt_prev_h   2000.0 -5.328476e+01  2.936127e+02   -3636.860000
# close_lt_prev_l   2000.0  7.765303e+01  3.262824e+02   -2134.220000
# vol_bo_long       2001.0  4.397801e-02  2.050975e-01       0.000000
# vol_bo_short      2001.0  2.098951e-02  1.433849e-01       0.000000
# 20day_high        1981.0  1.781440e+03  3.703828e+03      11.280000
# 20day_low         1981.0  1.119168e+03  2.123009e+03       9.740000
# range_bo_long     2001.0  1.549225e-01  3.619213e-01       0.000000
# range_bo_short    2001.0  5.997001e-02  2.374906e-01       0.000000
# ma20              1982.0  1.467799e+03  2.945191e+03      10.760000
# ma50              1952.0  1.418404e+03  2.830860e+03      11.432200
# ma100             1902.0  1.320269e+03  2.584553e+03      12.476900
# ma20_long         2001.0  5.827086e-01  4.932351e-01       0.000000
# ma20_short        2001.0  4.077961e-01  4.915477e-01       0.000000
# ma50_long         2001.0  6.351824e-01  4.814993e-01       0.000000
# ma50_short        2001.0  3.403298e-01  4.739385e-01       0.000000
# ma100_long        2001.0  6.111944e-01  4.876009e-01       0.000000
# ma100_short       2001.0  3.393303e-01  4.736004e-01       0.000000
# bb_high           1982.0  1.776660e+03  3.698968e+03      11.260400
# bb_low            1982.0  1.158937e+03  2.225744e+03     -25.435128
# bb_long           2001.0  8.495752e-02  2.788882e-01       0.000000
# bb_short          2001.0  1.849075e-01  3.883196e-01       0.000000
# pct_change_1day   2000.0  5.778986e-03  9.588954e-02      -0.572057
# pct_change_5day   1996.0  2.622575e-02  1.776168e-01      -0.698386
# pct_change_10day  1991.0  5.502004e-02  2.632007e-01      -0.807906
# pct_change_20day  1981.0  1.145239e-01  3.911444e-01      -0.881372
#
#                            25%           50%           75%           max
# open              2.358300e+02  4.426600e+02  8.941600e+02  1.934660e+04
# high              2.400100e+02  4.533700e+02  9.202600e+02  1.987062e+04
# low               2.317800e+02  4.311000e+02  8.483200e+02  1.875091e+04
# close             2.358500e+02  4.431800e+02  8.944100e+02  1.934549e+04
# volume            3.945871e+06  1.531576e+07  4.761919e+07  6.245732e+09
# 20day_ave_vol     4.378482e+06  1.669031e+07  4.653547e+07  2.907625e+09
# close_gt_prev_h  -1.909500e+01 -4.935000e+00  4.500000e-01  3.007110e+03
# close_lt_prev_l   1.267500e+00  7.775000e+00  3.240500e+01  5.188550e+03
# vol_bo_long       0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# vol_bo_short      0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# 20day_high        2.670200e+02  4.928000e+02  1.041040e+03  1.987062e+04
# 20day_low         2.142700e+02  3.869300e+02  7.256200e+02  1.196209e+04
# range_bo_long     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# range_bo_short    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ma20              2.364969e+02  4.441185e+02  8.782940e+02  1.627098e+04
# ma50              2.453798e+02  4.567016e+02  8.410160e+02  1.471381e+04
# ma100             2.541454e+02  4.765381e+02  7.653571e+02  1.237871e+04
# ma20_long         0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# ma20_short        0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# ma50_long         0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# ma50_short        0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# ma100_long        0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# ma100_short       0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# bb_high           2.579829e+02  4.857925e+02  1.042790e+03  2.120586e+04
# bb_low            2.149675e+02  3.994478e+02  7.194710e+02  1.284281e+04
# bb_long           0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# bb_short          0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# pct_change_1day  -1.160155e-02  2.148324e-03  2.100442e-02  3.368390e+00
# pct_change_5day  -2.943539e-02  1.088717e-02  6.715205e-02  4.316780e+00
# pct_change_10day -4.256660e-02  2.090000e-02  1.137923e-01  4.935640e+00
# pct_change_20day -7.348518e-02  4.702927e-02  1.758501e-01  4.602725e+00

# %% [markdown]
# Now lets take a look at a simple bar plot showing the number of trade signals for each strategy.

# %%
# Get the trade signal columns of the dataframe
cl_signals = cl_indicators[['vol_bo_long', 'vol_bo_short', 'range_bo_long', 'range_bo_short',
                       'ma20_long', 'ma20_short', 'ma50_long', 'ma50_short', 'ma100_long',
                       'ma100_short', 'bb_long', 'bb_short']]

# Put the strategy names and counts into lists
signal_names = [signal for signal in cl_signals.columns]
signal_counts = [cl_signals[signal].value_counts()[1] for signal in cl_signals.columns]

# Plot 
plt.figure(figsize=(10,7))
plt.bar(signal_names, signal_counts)
plt.title('Trade Counts\nper Signal')
plt.xlabel('Strategies')
plt.ylabel('No. of Trades')
plt.xticks(rotation=90)

plt.savefig('crude_trade_counts.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# And for Bitcoin

# %%
# Get the trade signal columns of the dataframe
btc_signals = btc_indicators[['vol_bo_long', 'vol_bo_short', 'range_bo_long', 'range_bo_short',
                       'ma20_long', 'ma20_short', 'ma50_long', 'ma50_short', 'ma100_long',
                       'ma100_short', 'bb_long', 'bb_short']]

# Put the strategy names and counts into lists
signal_names = [signal for signal in btc_signals.columns]
signal_counts = [btc_signals[signal].value_counts()[1] for signal in btc_signals.columns]

# Plot 
plt.figure(figsize=(10,7))
plt.bar(signal_names, signal_counts)
plt.title('Trade Counts\nper Signal')
plt.xlabel('Strategies')
plt.ylabel('No. of Trades')
plt.xticks(rotation=90)

plt.savefig('bitcoin_trade_counts.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Initial Exploration

# %% [markdown]
# Now that we have all the data and indicators that we need, it is time to explore the real question at hand, do any of these indicators do a good job of predicting future prices.
#
# In order to do this we will create a plot of the future returns of a product after each signal is triggered and see if the distribution is consistently around zero (no predictive value), above (positive predictive value), or below (negative predictive value).  Keep in mind that if we find an indicator that consistently predicts negative returns all we have to do is change the entry direction in order to create a winning strategy.

# %%
# Get the data for Crude Oil 50day long moving average signal, and mean return
cl_50ma_long = cl_indicators[cl_indicators['ma50_long'] == 1]
mean_pc = cl_50ma_long.pct_change_1day.mean()

# Plot the 1day returns
plt.figure(figsize=(14,7))

plt.plot(cl_50ma_long.index, cl_50ma_long.pct_change_1day, label='Daily Returns')
plt.plot(cl_50ma_long.index, [mean_pc]*len(cl_50ma_long.pct_change_1day),
            color='r', linestyle='--', label='Average Return')
plt.title('Daily Returns for Crude Oil\n50day MA Long Strategy')
plt.xlabel('Date')
plt.ylabel('Percent Return (1day)')
plt.legend(loc='best')

plt.savefig('crude_50ma_long_1day_returns.png', bbox_inches='tight')
plt.show()
print('Average return: {}'.format(mean_pc))
print('Number of trades: {}'.format(len(cl_50ma_long)))
# Out:
# Average return: 0.003441966559424432
# Number of trades: 1417

# %% [markdown]
# And for the short 50day moving aveage strategy

# %%
# Get the data for Crude Oil 50day long moving average signal, and mean return
cl_50ma_short = cl_indicators[cl_indicators['ma50_short'] == 1]
mean_pc = -1.0 * (cl_50ma_short.pct_change_1day.mean())

# Plot the 1day returns
plt.figure(figsize=(14,7))

plt.plot(cl_50ma_short.index, -1.0 * (cl_50ma_short.pct_change_1day), label='Daily Returns')
plt.plot(cl_50ma_short.index, [mean_pc]*len(cl_50ma_short.pct_change_1day),
            color='r', linestyle='--', label='Average Return')
plt.title('Daily Returns for Crude Oil\n50day MA Short Strategy')
plt.xlabel('Date')
plt.ylabel('Percent Return (1day)')
plt.legend(loc='best')

plt.savefig('crude_50ma_short_1day_returns.png', bbox_inches='tight')
plt.show()
print('Average return: {}'.format(mean_pc))
print('Number of trades: {}'.format(len(cl_50ma_short)))
# Out:
# Average return: 0.004114335121237718
# Number of trades: 1051

# %% [markdown]
# So this looks like a good start.  With any trading strategy it is good to see positive results in each direction of trade.  It is a very simple way to show this is possibly a robust strategy, not one that finds winners in one direction but would just give back those gains on signals in the other direction.
#
# From here we will create a function to analyze this **signal-return** relationship for each signal, and for each timeframe of returns.

# %% [markdown]
# First I abstract this last analysis section out into a functon to be used to explore other signal-return relationships.

# %%
def plot_returns(df, signal, timeframe=1):
    ''' This function takes in a dataframe of price and indicator information, as well as the
        signal and timeframe for desired analysis.  It then plots a line chart of the percent
        returns over the given timeframe, for each signal in the dataset.
        
        Args: df - dataframe of price and indicator information
              signal - string name of the desired indicator signal
              timeframe - int of number of days into the future to show returns for (1, 5, 10, 20)
        
        Return: None - plots the input information
    '''
    # Get the relevant data from the dataframe and set timeframe string
    df_signal = df[df[signal] == 1]
    returns = 'pct_change_{}day'.format(timeframe)
    
    # Find out if signal is long or short and calculate the mean
    is_long = re.search('long$', signal)
    is_short = re.search('short$', signal)
    
    if is_long:
        mean_pc = df_signal[returns].mean()
    elif is_short:
        mean_pc = -1.0 * df_signal[returns].mean()
    else:
        return 'No such trading strategy'

    # Plot the 1day returns
    plt.figure(figsize=(14,7))
    
    if is_long:
        plt.plot(df_signal.index, df_signal[returns], label='Daily Returns')
    else:
        plt.plot(df_signal.index, -1.0 * (df_signal[returns]), label='Daily Returns')

    plt.plot(df_signal.index, [mean_pc]*len(df_signal[returns]),
                color='r', linestyle='--', label='Average Return')
    
    plt.title('Returns\nStrategy: {}\nTimeframe: {}'.format(signal, returns))
    plt.xlabel('Date')
    plt.ylabel('{}'.format(returns))
    plt.legend(loc='best')

    plt.show()
    print('Average return: {}'.format(mean_pc))
    print('Number of trades: {}'.format(len(df_signal)))

# %% [markdown]
# Now to create a function that can summarize important return statistics so we can compare signals across products, sectors, timeframes, etc.

# %%
def return_stats(product, df, signal, timeframe=1):
    ''' This function takes in a product, dataframe of price and indicator information, as well as a
        trading strategy signal and a timeframe, then returns important statistics about the
        percentage returns of the strategy over the total dataset, which is used for further analysis.
        
        Args: df - dataframe of price and indicator information
              signal - string name of the desired indicator signal
              timeframe - int of number of days into the future to show returns for (1, 5, 10, 20)
        
        Return: list [product, signal, timeframe, signals per day, mean return, std return, min, max, 25%, 75%]
    '''
    # Get the relevant data from the dataframe and set timeframe string
    df_signal = df[df[signal] == 1]
    returns = 'pct_change_{}day'.format(timeframe)
    
    # Find out if signal is long or short and calculate the mean
    is_long = re.search('long$', signal)
    is_short = re.search('short$', signal)
    
    if is_long:
        mean_pc = df_signal[returns].mean()
    elif is_short:
        mean_pc = -1.0 * df_signal[returns].mean()
    else:
        return 'No such trading strategy'
    
    # Calculate return statistics
    signal_count = len(df_signal)
    signals_per_day = len(df_signal) / len(df)
    std_pc = df_signal[returns].std()
    min_pc = df_signal[returns].min()
    max_pc = df_signal[returns].max()
    q25_pc = df_signal[returns].quantile(q=0.25)
    q75_pc = df_signal[returns].quantile(q=0.75)
    
    return [product, signal, timeframe, signal_count, signals_per_day, mean_pc, std_pc, min_pc, max_pc, q25_pc, q75_pc]

# %% [markdown]
# Here is an example of the Crude Oil stats for the 50day moving average long strategy for 1day returns.

# %%
cl_50ma_long_stats = return_stats('CL', cl, 'ma50_long')

# Print summary
print('Total number of signals: {}'.format(cl_50ma_long_stats[3]))
print('Number of signals per trading day: {0:.2f}'.format(cl_50ma_long_stats[4]))
print('Average return: {:.2%}'.format(cl_50ma_long_stats[5]))
print('Standard deviation of return: {:.2%}'.format(cl_50ma_long_stats[6]))
print('Minimum return: {:.2%}'.format(cl_50ma_long_stats[7]))
print('Maximum return: {:.2%}'.format(cl_50ma_long_stats[8]))
print('25th percentile return: {:.2%}'.format(cl_50ma_long_stats[9]))
print('75th percentile return: {:.2%}'.format(cl_50ma_long_stats[10]))
# Out:
# Total number of signals: 1417
# Number of signals per trading day: 0.56
# Average return: 0.34%
# Standard deviation of return: 1.85%
# Minimum return: -7.58%
# Maximum return: 11.10%
# 25th percentile return: -0.74%
# 75th percentile return: 1.39%

# %% [markdown]
# These stats that we have for each signal and timeframe are important to look at, and our main analysis is based on determining whether or not we can find consistent returns across strategies, products, sectors, timeframes, etc.  The best way to do this would be to have all this return data stored in a dataframe, with the corresponding product, signal, timeframe, etc.
#
# So the final task here is to create a blank dataframe with the column headers and iterate through the prod_dict, for each trade signal, and for each timeframe, then enter the relevant data into the dataframe.  That will be the goal of these next few cells.  From there it will just be visualizing our findings.

# %%
# Create the dataframe, a list of all signals and a list of all timeframes
returns_df = pd.DataFrame(columns=['product', 'signal', 'timeframe',
                              'signal_count', 'signals_per_day', 'ave_return', 'std_return',
                              'min_return', 'max_return', 'q25_return', 'q75_return'])

signal_list = ['vol_bo_long', 'vol_bo_short', 'range_bo_long', 'range_bo_short',
                       'ma20_long', 'ma20_short', 'ma50_long', 'ma50_short', 'ma100_long',
                       'ma100_short', 'bb_long', 'bb_short']

timeframe_list = [1, 5, 10, 20]

# %% [markdown]
# Before we get into adding all the data to this new dataframe, we need to remember that not all the `prod_dict` dfs have been cleaned and processed with indicator columns yet.  We have only shown examples of a few.  So here we clean and process all dfs in the main dict.

# %%
# Get a list of symbols without CL and BTC, since we already processed them for examples
symbols = list(prod_dict.keys())
symbols.remove('CL')
symbols.remove('BTC')

# Iterate through prod_dict for symbol in symbols and apply add_all_indicators
for prod, df in prod_dict.items():
    if prod in symbols:
        add_all_indicators(df)

# %% [markdown]
# Check to see that the columns have been appended properly.

# %%
gc = prod_dict['GC']
gc.tail()
# Out:
#               open    high     low   close    volume  20day_ave_vol  \
# Date
# 2014-12-24  1176.8  1181.2  1172.7  1173.5   43632.0      158831.94
# 2014-12-26  1175.2  1199.1  1175.2  1195.3   67481.0      152136.58
# 2014-12-29  1194.9  1197.5  1178.6  1181.9   86152.0      150354.58
# 2014-12-30  1182.9  1210.9  1180.5  1200.4  142350.0      144371.55
# 2014-12-31  1199.8  1203.9  1179.5  1184.1   71734.0      134341.95
#
#             close_gt_prev_h  close_lt_prev_l  vol_bo_long  vol_bo_short  \
# Date
# 2014-12-24            -11.4              1.1          0.0           0.0
# 2014-12-26             14.1             22.6          0.0           0.0
# 2014-12-29            -17.2              6.7          0.0           0.0
# 2014-12-30              2.9             21.8          0.0           0.0
# 2014-12-31            -26.8              3.6          0.0           0.0
#
#                   ...         ma100_long  ma100_short      bb_high  \
# Date              ...
# 2014-12-24        ...                  0            1  1236.481767
# 2014-12-26        ...                  0            1  1236.441338
# 2014-12-29        ...                  0            1  1235.896807
# 2014-12-30        ...                  0            1  1234.089504
# 2014-12-31        ...                  0            1  1234.098943
#
#                  bb_low  bb_long  bb_short  pct_change_1day  pct_change_5day  \
# Date
# 2014-12-24  1165.506233        0         0        -0.003820        -0.017581
# 2014-12-26  1165.362662        0         0         0.018577         0.000418
# 2014-12-29  1166.553193        0         0        -0.011211        -0.011789
# 2014-12-30  1166.590496        0         0         0.015653         0.017461
# 2014-12-31  1165.051057        0         0        -0.013579         0.005178
#
#             pct_change_10day  pct_change_20day
# Date
# 2014-12-24         -0.045469         -0.019944
# 2014-12-26         -0.024723         -0.001537
# 2014-12-29         -0.033211          0.005496
# 2014-12-30         -0.006045         -0.014531
# 2014-12-31         -0.008541         -0.012756
#
# [5 rows x 31 columns]

# %%
xrp = prod_dict['XRP']
xrp.tail()
# Out:
#               open    high     low   close       volume  20day_ave_vol  \
# Date
# 2018-03-28  0.5733  0.5745  0.4975  0.5031  68842916.04   6.388486e+07
# 2018-03-29  0.5031  0.5257  0.4715  0.4990  71841509.56   6.096812e+07
# 2018-03-30  0.4989  0.5219  0.4929  0.5003  33649410.94   6.201250e+07
# 2018-03-31  0.5003  0.5078  0.4552  0.4787  39051078.63   6.059320e+07
# 2018-04-01  0.4787  0.4846  0.4726  0.4846    591538.79   6.009506e+07
#
#             close_gt_prev_h  close_lt_prev_l  vol_bo_long  vol_bo_short  \
# Date
# 2018-03-28          -0.0855          -0.0620          0.0           0.0
# 2018-03-29          -0.0755           0.0015          0.0           0.0
# 2018-03-30          -0.0254           0.0288          0.0           0.0
# 2018-03-31          -0.0432          -0.0142          0.0           0.0
# 2018-04-01          -0.0232           0.0294          0.0           0.0
#
#                   ...         ma100_long  ma100_short   bb_high    bb_low  \
# Date              ...
# 2018-03-28        ...                  0            1  0.828150  0.508650
# 2018-03-29        ...                  0            1  0.823025  0.486175
# 2018-03-30        ...                  0            1  0.802300  0.475200
# 2018-03-31        ...                  0            1  0.787404  0.459746
# 2018-04-01        ...                  0            1  0.767036  0.450804
#
#             bb_long  bb_short  pct_change_1day  pct_change_5day  \
# Date
# 2018-03-28        1         0        -0.122449        -0.200159
# 2018-03-29        1         0        -0.008149        -0.213058
# 2018-03-30        0         0         0.002605        -0.148281
# 2018-03-31        1         0        -0.043174        -0.160617
# 2018-04-01        0         0         0.012325        -0.154718
#
#             pct_change_10day  pct_change_20day
# Date
# 2018-03-28         -0.301541         -0.389145
# 2018-03-29         -0.286735         -0.356129
# 2018-03-30         -0.262747         -0.387862
# 2018-03-31         -0.266135         -0.388008
# 2018-04-01         -0.243285         -0.376881
#
# [5 rows x 31 columns]

# %% [markdown]
# Now that we have all the right columns for each dataframe we can put the return data into our blank dataframe.

# %%
add_all_indicators(prod_dict['BTC'])
# Out:
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Frank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                 open      high       low     close        volume  \
# Date
# 2012-10-25     10.86     10.95      9.74     10.17  1.020617e+06
# 2012-10-26     10.17     10.84      9.82     10.26  4.967475e+05
# 2012-10-27     10.26     10.95     10.25     10.70  2.366405e+05
# 2012-10-28     10.70     10.94     10.32     10.60  4.001735e+05
# 2012-10-29     10.60     10.89     10.58     10.89  2.798431e+05
# 2012-10-30     10.89     11.21     10.71     11.20  4.483598e+05
# 2012-10-31     11.20     11.28     10.40     10.57  5.503275e+05
# 2012-11-01     10.57     10.80     10.33     10.47  2.589578e+05
# 2012-11-02     10.47     10.65     10.40     10.64  1.763451e+05
# 2012-11-03     10.64     10.90     10.51     10.80  1.787617e+05
# 2012-11-04     10.80     10.88     10.61     10.75  2.336504e+05
# 2012-11-05     10.75     10.90     10.67     10.90  2.915159e+05
# 2012-11-06     10.90     11.22     10.80     10.92  3.484747e+05
# 2012-11-07     10.92     11.07     10.75     10.93  2.845561e+05
# 2012-11-08     10.93     10.98     10.79     10.82  1.599849e+05
# 2012-11-09     10.82     10.96     10.75     10.89  1.463493e+05
# 2012-11-10     10.89     10.94     10.70     10.87  1.364481e+05
# 2012-11-11     10.87     11.18     10.77     11.01  4.310805e+05
# 2012-11-12     11.01     11.13     10.92     10.95  1.843688e+05
# 2012-11-13     10.95     11.05     10.82     10.95  2.686368e+05
# 2012-11-14     10.95     11.30     10.86     11.20  3.533562e+05
# 2012-11-15     11.20     11.80     11.17     11.75  6.694222e+05
# 2012-11-16     11.75     11.80     11.52     11.79  2.230395e+05
# 2012-11-17     11.79     11.83     11.62     11.65  1.817170e+05
# 2012-11-18     11.65     11.84     11.60     11.80  2.952608e+05
# 2012-11-19     11.80     11.80     11.57     11.73  3.182912e+05
# 2012-11-20     11.73     11.78     11.64     11.77  2.253087e+05
# 2012-11-21     11.77     12.43     11.67     12.42  7.035829e+05
# 2012-11-22     12.42     12.41     12.13     12.35  2.333709e+05
# 2012-11-23     12.35     12.48     12.25     12.41  2.420586e+05
# ...              ...       ...       ...       ...           ...
# 2018-03-03  11465.36  11539.79  11084.01  11504.42  6.907273e+08
# 2018-03-04  11503.94  11694.15  11431.55  11440.73  7.914719e+08
# 2018-03-05  11440.33  11441.65  10589.28  10735.45  1.210081e+09
# 2018-03-06  10735.45  10913.70   9470.73   9928.56  1.858869e+09
# 2018-03-07   9928.56  10119.21   9086.85   9316.72  1.492236e+09
# 2018-03-08   9316.77   9433.38   8393.45   9252.76  2.081621e+09
# 2018-03-09   9252.76   9518.62   8727.43   8797.27  1.084926e+09
# 2018-03-10   8797.27   9735.64   8484.32   9544.84  1.374815e+09
# 2018-03-11   9543.98   9907.41   8796.52   9142.15  1.435404e+09
# 2018-03-12   9142.27   9486.12   8856.65   9160.12  1.228556e+09
# 2018-03-13   9160.12   9360.66   7966.94   8217.70  1.385573e+09
# 2018-03-14   8216.22   8432.12   7698.47   8268.41  1.519850e+09
# 2018-03-15   8267.95   8616.63   7924.11   8283.23  1.082790e+09
# 2018-03-16   8283.23   8360.64   7765.41   7883.45  9.019394e+08
# 2018-03-17   7882.67   8299.86   7318.46   8215.40  1.535519e+09
# 2018-03-18   8215.50   8725.60   8129.66   8623.14  1.447813e+09
# 2018-03-19   8623.14   9056.23   8339.80   8920.71  1.150462e+09
# 2018-03-20   8920.53   9184.51   8778.69   8911.35  9.913764e+08
# 2018-03-21   8911.37   9107.00   8500.88   8724.98  1.023287e+09
# 2018-03-22   8724.98   8935.88   8307.58   8934.80  9.399973e+08
# 2018-03-23   8935.51   9036.23   8515.53   8548.06  8.276632e+08
# 2018-03-24   8548.39   8690.36   8395.85   8472.84  6.576435e+08
# 2018-03-25   8472.56   8521.04   7869.27   8152.20  1.079039e+09
# 2018-03-26   8152.18   8226.24   7752.30   7808.48  9.307550e+08
# 2018-03-27   7808.42   8117.79   7752.60   7959.78  6.577121e+08
# 2018-03-28   7959.78   7983.77   6927.11   7106.62  1.379180e+09
# 2018-03-29   7106.62   7280.27   6595.26   6853.76  1.584675e+09
# 2018-03-30   6853.75   7228.40   6806.34   6943.77  9.154006e+08
# 2018-03-31   6943.77   7056.22   6463.54   6835.84  8.898877e+08
# 2018-04-01   6835.58   6999.52   6792.30   6999.52  1.342822e+07
#
#             20day_ave_vol  close_gt_prev_h  close_lt_prev_l  vol_bo_long  \
# Date
# 2012-10-25            NaN              NaN              NaN          0.0
# 2012-10-26            NaN            -0.69             0.52          0.0
# 2012-10-27            NaN            -0.14             0.88          0.0
# 2012-10-28            NaN            -0.35             0.35          0.0
# 2012-10-29            NaN            -0.05             0.57          0.0
# 2012-10-30            NaN             0.31             0.62          0.0
# 2012-10-31            NaN            -0.64            -0.14          0.0
# 2012-11-01            NaN            -0.81             0.07          0.0
# 2012-11-02            NaN            -0.16             0.31          0.0
# 2012-11-03            NaN             0.15             0.40          0.0
# 2012-11-04            NaN            -0.15             0.24          0.0
# 2012-11-05            NaN             0.02             0.29          0.0
# 2012-11-06            NaN             0.02             0.25          0.0
# 2012-11-07            NaN            -0.29             0.13          0.0
# 2012-11-08            NaN            -0.25             0.07          0.0
# 2012-11-09            NaN            -0.09             0.10          0.0
# 2012-11-10            NaN            -0.09             0.12          0.0
# 2012-11-11            NaN             0.07             0.31          0.0
# 2012-11-12            NaN            -0.23             0.18          0.0
# 2012-11-13            NaN            -0.18             0.03          0.0
# 2012-11-14   3.265919e+05             0.15             0.38          0.0
# 2012-11-15   2.932289e+05             0.45             0.89          1.0
# 2012-11-16   3.018626e+05            -0.01             0.62          0.0
# 2012-11-17   3.011826e+05            -0.15             0.13          0.0
# 2012-11-18   2.902598e+05            -0.03             0.18          0.0
# 2012-11-19   2.910306e+05            -0.11             0.13          0.0
# 2012-11-20   2.845272e+05            -0.03             0.20          0.0
# 2012-11-21   2.682763e+05             0.64             0.78          1.0
# 2012-11-22   2.905075e+05            -0.08             0.68          0.0
# 2012-11-23   2.933588e+05             0.00             0.28          0.0
# ...                   ...              ...              ...          ...
# 2018-03-03   1.245252e+09           -26.24           461.30          0.0
# 2018-03-04   1.225492e+09           -99.06           356.72          0.0
# 2018-03-05   1.222399e+09          -958.70          -696.10          0.0
# 2018-03-06   1.221860e+09         -1513.09          -660.72          0.0
# 2018-03-07   1.231470e+09         -1596.98          -154.01          0.0
# 2018-03-08   1.252991e+09          -866.45           165.91          0.0
# 2018-03-09   1.290676e+09          -636.11           403.82          0.0
# 2018-03-10   1.261937e+09            26.22           817.41          0.0
# 2018-03-11   1.271351e+09          -593.49           657.83          0.0
# 2018-03-12   1.261104e+09          -747.29           363.60          0.0
# 2018-03-13   1.223396e+09         -1268.42          -638.95          0.0
# 2018-03-14   1.202877e+09         -1092.25           301.47          0.0
# 2018-03-15   1.208897e+09          -148.89           584.76          0.0
# 2018-03-16   1.200812e+09          -733.18           -40.66          0.0
# 2018-03-17   1.206254e+09          -145.24           449.99          0.0
# 2018-03-18   1.223944e+09           323.28          1304.68          0.0
# 2018-03-19   1.243292e+09           195.11           791.05          0.0
# 2018-03-20   1.244512e+09          -144.88           571.55          0.0
# 2018-03-21   1.246457e+09          -459.53           -53.71          0.0
# 2018-03-22   1.254976e+09          -172.20           433.92          0.0
# 2018-03-23   1.261366e+09          -387.82           240.48          0.0
# 2018-03-24   1.268213e+09          -563.39           -42.69          0.0
# 2018-03-25   1.261521e+09          -538.16          -243.65          0.0
# 2018-03-26   1.254969e+09          -712.56           -60.79          0.0
# 2018-03-27   1.208563e+09          -266.46           207.48          0.0
# 2018-03-28   1.166837e+09         -1011.17          -645.98          0.0
# 2018-03-29   1.131715e+09         -1130.01           -73.35          0.0
# 2018-03-30   1.156703e+09          -336.50           348.51          0.0
# 2018-03-31   1.133732e+09          -392.56            29.50          0.0
# 2018-04-01   1.106456e+09           -56.70           535.98          0.0
#
#             vol_bo_short        ...         ma100_long  ma100_short  \
# Date                            ...
# 2012-10-25           0.0        ...                  0            0
# 2012-10-26           0.0        ...                  0            0
# 2012-10-27           0.0        ...                  0            0
# 2012-10-28           0.0        ...                  0            0
# 2012-10-29           0.0        ...                  0            0
# 2012-10-30           0.0        ...                  0            0
# 2012-10-31           0.0        ...                  0            0
# 2012-11-01           0.0        ...                  0            0
# 2012-11-02           0.0        ...                  0            0
# 2012-11-03           0.0        ...                  0            0
# 2012-11-04           0.0        ...                  0            0
# 2012-11-05           0.0        ...                  0            0
# 2012-11-06           0.0        ...                  0            0
# 2012-11-07           0.0        ...                  0            0
# 2012-11-08           0.0        ...                  0            0
# 2012-11-09           0.0        ...                  0            0
# 2012-11-10           0.0        ...                  0            0
# 2012-11-11           0.0        ...                  0            0
# 2012-11-12           0.0        ...                  0            0
# 2012-11-13           0.0        ...                  0            0
# 2012-11-14           0.0        ...                  0            0
# 2012-11-15           0.0        ...                  0            0
# 2012-11-16           0.0        ...                  0            0
# 2012-11-17           0.0        ...                  0            0
# 2012-11-18           0.0        ...                  0            0
# 2012-11-19           0.0        ...                  0            0
# 2012-11-20           0.0        ...                  0            0
# 2012-11-21           0.0        ...                  0            0
# 2012-11-22           0.0        ...                  0            0
# 2012-11-23           0.0        ...                  0            0
# ...                  ...        ...                ...          ...
# 2018-03-03           0.0        ...                  0            1
# 2018-03-04           0.0        ...                  0            1
# 2018-03-05           0.0        ...                  0            1
# 2018-03-06           0.0        ...                  0            1
# 2018-03-07           0.0        ...                  0            1
# 2018-03-08           0.0        ...                  0            1
# 2018-03-09           0.0        ...                  0            1
# 2018-03-10           0.0        ...                  0            1
# 2018-03-11           0.0        ...                  0            1
# 2018-03-12           0.0        ...                  0            1
# 2018-03-13           0.0        ...                  0            1
# 2018-03-14           0.0        ...                  0            1
# 2018-03-15           0.0        ...                  0            1
# 2018-03-16           0.0        ...                  0            1
# 2018-03-17           0.0        ...                  0            1
# 2018-03-18           0.0        ...                  0            1
# 2018-03-19           0.0        ...                  0            1
# 2018-03-20           0.0        ...                  0            1
# 2018-03-21           0.0        ...                  0            1
# 2018-03-22           0.0        ...                  0            1
# 2018-03-23           0.0        ...                  0            1
# 2018-03-24           0.0        ...                  0            1
# 2018-03-25           0.0        ...                  0            1
# 2018-03-26           0.0        ...                  0            1
# 2018-03-27           0.0        ...                  0            1
# 2018-03-28           0.0        ...                  0            1
# 2018-03-29           0.0        ...                  0            1
# 2018-03-30           0.0        ...                  0            1
# 2018-03-31           0.0        ...                  0            1
# 2018-04-01           0.0        ...                  0            1
#
#                  bb_high       bb_low  bb_long  bb_short  pct_change_1day  \
# Date
# 2012-10-25           NaN          NaN        0         0              NaN
# 2012-10-26           NaN          NaN        0         0         0.008850
# 2012-10-27           NaN          NaN        0         0         0.042885
# 2012-10-28           NaN          NaN        0         0        -0.009346
# 2012-10-29           NaN          NaN        0         0         0.027358
# 2012-10-30           NaN          NaN        0         0         0.028466
# 2012-10-31           NaN          NaN        0         0        -0.056250
# 2012-11-01           NaN          NaN        0         0        -0.009461
# 2012-11-02           NaN          NaN        0         0         0.016237
# 2012-11-03           NaN          NaN        0         0         0.015038
# 2012-11-04           NaN          NaN        0         0        -0.004630
# 2012-11-05           NaN          NaN        0         0         0.013953
# 2012-11-06           NaN          NaN        0         0         0.001835
# 2012-11-07           NaN          NaN        0         0         0.000916
# 2012-11-08           NaN          NaN        0         0        -0.010064
# 2012-11-09           NaN          NaN        0         0         0.006470
# 2012-11-10           NaN          NaN        0         0        -0.001837
# 2012-11-11           NaN          NaN        0         0         0.012879
# 2012-11-12           NaN          NaN        0         0        -0.005450
# 2012-11-13     11.270276    10.258724        0         0         0.000000
# 2012-11-14     11.274437    10.357563        0         1         0.022831
# 2012-11-15     11.443101    10.337899        0         1         0.049107
# 2012-11-16     11.619950    10.270050        0         1         0.003404
# 2012-11-17     11.721055    10.273945        0         1        -0.011874
# 2012-11-18     11.847961    10.238039        0         0         0.012876
# 2012-11-19     11.929255    10.209745        0         0        -0.005932
# 2012-11-20     12.009727    10.249273        0         0         0.003410
# 2012-11-21     12.223903    10.230097        0         1         0.055225
# 2012-11-22     12.387672    10.237328        0         1        -0.005636
# 2012-11-23     12.544952    10.241048        0         0         0.004858
# ...                  ...          ...      ...       ...              ...
# 2018-03-03  11922.623598  8899.866402        0         0         0.003407
# 2018-03-04  11854.363273  9257.730727        0         0        -0.005536
# 2018-03-05  11816.345364  9420.729636        0         0        -0.061646
# 2018-03-06  11822.764342  9403.791658        0         0        -0.075161
# 2018-03-07  11900.397394  9238.957606        1         0        -0.061624
# 2018-03-08  11906.275250  9048.634750        1         0        -0.006865
# 2018-03-09  12011.220190  8781.693810        1         0        -0.049227
# 2018-03-10  11927.631089  8701.538911        1         0         0.084977
# 2018-03-11  11839.055480  8578.686520        0         0        -0.042189
# 2018-03-12  11832.469974  8453.118026        0         0         0.001966
# 2018-03-13  11955.729716  8166.832284        1         0        -0.102883
# 2018-03-14  12021.313392  7910.538608        1         0         0.006171
# 2018-03-15  12082.302381  7707.299619        0         0         0.001792
# 2018-03-16  12172.449344  7444.486656        0         0        -0.048264
# 2018-03-17  12156.336317  7249.489683        0         0         0.042107
# 2018-03-18  12065.301546  7143.362454        0         0         0.049631
# 2018-03-19  11987.519450  7079.771550        0         0         0.034508
# 2018-03-20  11809.726091  7055.762909        0         0        -0.001049
# 2018-03-21  11586.853950  7046.821050        0         0        -0.020914
# 2018-03-22  11226.107379  7154.511621        0         0         0.024048
# 2018-03-23  10777.979937  7307.003063        0         0        -0.043285
# 2018-03-24  10227.012833  7561.181167        0         0        -0.008800
# 2018-03-25   9817.783086  7712.085914        0         0        -0.037843
# 2018-03-26   9643.161125  7674.699875        0         0        -0.042163
# 2018-03-27   9571.462827  7610.704173        0         0         0.019376
# 2018-03-28   9617.095099  7350.457901        1         0        -0.107184
# 2018-03-29   9722.010776  7051.191224        1         0        -0.035581
# 2018-03-30   9623.274823  6889.820177        1         0         0.013133
# 2018-03-31   9580.595654  6701.868346        1         0        -0.015543
# 2018-04-01   9474.901335  6591.502665        0         0         0.023944
#
#             pct_change_5day  pct_change_10day  pct_change_20day
# Date
# 2012-10-25              NaN               NaN               NaN
# 2012-10-26              NaN               NaN               NaN
# 2012-10-27              NaN               NaN               NaN
# 2012-10-28              NaN               NaN               NaN
# 2012-10-29              NaN               NaN               NaN
# 2012-10-30         0.101278               NaN               NaN
# 2012-10-31         0.030214               NaN               NaN
# 2012-11-01        -0.021495               NaN               NaN
# 2012-11-02         0.003774               NaN               NaN
# 2012-11-03        -0.008264               NaN               NaN
# 2012-11-04        -0.040179          0.057030               NaN
# 2012-11-05         0.031220          0.062378               NaN
# 2012-11-06         0.042980          0.020561               NaN
# 2012-11-07         0.027256          0.031132               NaN
# 2012-11-08         0.001852         -0.006428               NaN
# 2012-11-09         0.013023         -0.027679               NaN
# 2012-11-10        -0.002752          0.028382               NaN
# 2012-11-11         0.008242          0.051576               NaN
# 2012-11-12         0.001830          0.029135               NaN
# 2012-11-13         0.012015          0.013889               NaN
# 2012-11-14         0.028466          0.041860          0.101278
# 2012-11-15         0.080957          0.077982          0.145224
# 2012-11-16         0.070845          0.079670          0.101869
# 2012-11-17         0.063927          0.065874          0.099057
# 2012-11-18         0.077626          0.090573          0.083563
# 2012-11-19         0.047321          0.077135          0.047321
# 2012-11-20         0.001702          0.082797          0.113529
# 2012-11-21         0.053435          0.128065          0.186246
# 2012-11-22         0.060086          0.127854          0.160714
# 2012-11-23         0.051695          0.133333          0.149074
# ...                     ...               ...               ...
# 2018-03-03         0.085859          0.168203          0.290997
# 2018-03-04         0.107049          0.124340          0.338929
# 2018-03-05        -0.017743          0.106094          0.131758
# 2018-03-06        -0.100928          0.033137         -0.010484
# 2018-03-07        -0.187403         -0.097785         -0.085586
# 2018-03-08        -0.195721         -0.126666         -0.166208
# 2018-03-09        -0.231057         -0.148742         -0.155508
# 2018-03-10        -0.110905         -0.126680         -0.146432
# 2018-03-11        -0.079207         -0.172141         -0.187829
# 2018-03-12        -0.016808         -0.201061         -0.126081
# 2018-03-13        -0.111865         -0.285692         -0.165543
# 2018-03-14        -0.060116         -0.277283         -0.187421
# 2018-03-15        -0.132177         -0.228423         -0.146563
# 2018-03-16        -0.137681         -0.205983         -0.179671
# 2018-03-17        -0.103134         -0.118209         -0.204435
# 2018-03-18         0.049337         -0.068047         -0.186094
# 2018-03-19         0.078891          0.014032         -0.136798
# 2018-03-20         0.075830         -0.066370         -0.184642
# 2018-03-21         0.106746         -0.045631         -0.209917
# 2018-03-22         0.087567         -0.024598         -0.220714
# 2018-03-23        -0.008707          0.040201         -0.256976
# 2018-03-24        -0.050206          0.024724         -0.259414
# 2018-03-25        -0.085189         -0.015819         -0.240628
# 2018-03-26        -0.105043         -0.009510         -0.213533
# 2018-03-27        -0.109126         -0.031115         -0.145646
# 2018-03-28        -0.168628         -0.175866         -0.231946
# 2018-03-29        -0.191091         -0.231702         -0.220922
# 2018-03-30        -0.148234         -0.220795         -0.272511
# 2018-03-31        -0.124562         -0.216521         -0.252272
# 2018-04-01        -0.120639         -0.216600         -0.235870
#
# [1985 rows x 31 columns]

# %%
# Set variable to keep track of index in dataframe
i = 0

# Iterate through each product, for each signal, for each timeframe    
for prod, df in prod_dict.items():
    for signal in signal_list:
        for timeframe in timeframe_list:
            # Insert row of data into dataframe
            returns_df.loc[i] = return_stats(prod, df, signal, timeframe)
            i += 1
# Out:
# CL vol_bo_long 1
# CL vol_bo_long 5
# CL vol_bo_long 10
# CL vol_bo_long 20
# CL vol_bo_short 1
# CL vol_bo_short 5
# CL vol_bo_short 10
# CL vol_bo_short 20
# CL range_bo_long 1
# CL range_bo_long 5
# CL range_bo_long 10
# CL range_bo_long 20
# CL range_bo_short 1
# CL range_bo_short 5
# CL range_bo_short 10
# CL range_bo_short 20
# CL ma20_long 1
# CL ma20_long 5
# CL ma20_long 10
# CL ma20_long 20
# CL ma20_short 1
# CL ma20_short 5
# CL ma20_short 10
# CL ma20_short 20
# CL ma50_long 1
# CL ma50_long 5
# CL ma50_long 10
# CL ma50_long 20
# CL ma50_short 1
# CL ma50_short 5
# CL ma50_short 10
# CL ma50_short 20
# CL ma100_long 1
# CL ma100_long 5
# CL ma100_long 10
# CL ma100_long 20
# CL ma100_short 1
# CL ma100_short 5
# CL ma100_short 10
# CL ma100_short 20
# CL bb_long 1
# CL bb_long 5
# CL bb_long 10
# CL bb_long 20
# CL bb_short 1
# CL bb_short 5
# CL bb_short 10
# CL bb_short 20
# HO vol_bo_long 1
# HO vol_bo_long 5
# HO vol_bo_long 10
# HO vol_bo_long 20
# HO vol_bo_short 1
# HO vol_bo_short 5
# HO vol_bo_short 10
# HO vol_bo_short 20
# HO range_bo_long 1
# HO range_bo_long 5
# HO range_bo_long 10
# HO range_bo_long 20
# HO range_bo_short 1
# HO range_bo_short 5
# HO range_bo_short 10
# HO range_bo_short 20
# HO ma20_long 1
# HO ma20_long 5
# HO ma20_long 10
# HO ma20_long 20
# HO ma20_short 1
# HO ma20_short 5
# HO ma20_short 10
# HO ma20_short 20
# HO ma50_long 1
# HO ma50_long 5
# HO ma50_long 10
# HO ma50_long 20
# HO ma50_short 1
# HO ma50_short 5
# HO ma50_short 10
# HO ma50_short 20
# HO ma100_long 1
# HO ma100_long 5
# HO ma100_long 10
# HO ma100_long 20
# HO ma100_short 1
# HO ma100_short 5
# HO ma100_short 10
# HO ma100_short 20
# HO bb_long 1
# HO bb_long 5
# HO bb_long 10
# HO bb_long 20
# HO bb_short 1
# HO bb_short 5
# HO bb_short 10
# HO bb_short 20
# NG vol_bo_long 1
# NG vol_bo_long 5
# NG vol_bo_long 10
# NG vol_bo_long 20
# NG vol_bo_short 1
# NG vol_bo_short 5
# NG vol_bo_short 10
# NG vol_bo_short 20
# NG range_bo_long 1
# NG range_bo_long 5
# NG range_bo_long 10
# NG range_bo_long 20
# NG range_bo_short 1
# NG range_bo_short 5
# NG range_bo_short 10
# NG range_bo_short 20
# NG ma20_long 1
# NG ma20_long 5
# NG ma20_long 10
# NG ma20_long 20
# NG ma20_short 1
# NG ma20_short 5
# NG ma20_short 10
# NG ma20_short 20
# NG ma50_long 1
# NG ma50_long 5
# NG ma50_long 10
# NG ma50_long 20
# NG ma50_short 1
# NG ma50_short 5
# NG ma50_short 10
# NG ma50_short 20
# NG ma100_long 1
# NG ma100_long 5
# NG ma100_long 10
# NG ma100_long 20
# NG ma100_short 1
# NG ma100_short 5
# NG ma100_short 10
# NG ma100_short 20
# NG bb_long 1
# NG bb_long 5
# NG bb_long 10
# NG bb_long 20
# NG bb_short 1
# NG bb_short 5
# NG bb_short 10
# NG bb_short 20
# GC vol_bo_long 1
# GC vol_bo_long 5
# GC vol_bo_long 10
# GC vol_bo_long 20
# GC vol_bo_short 1
# GC vol_bo_short 5
# GC vol_bo_short 10
# GC vol_bo_short 20
# GC range_bo_long 1
# GC range_bo_long 5
# GC range_bo_long 10
# GC range_bo_long 20
# GC range_bo_short 1
# GC range_bo_short 5
# GC range_bo_short 10
# GC range_bo_short 20
# GC ma20_long 1
# GC ma20_long 5
# GC ma20_long 10
# GC ma20_long 20
# GC ma20_short 1
# GC ma20_short 5
# GC ma20_short 10
# GC ma20_short 20
# GC ma50_long 1
# GC ma50_long 5
# GC ma50_long 10
# GC ma50_long 20
# GC ma50_short 1
# GC ma50_short 5
# GC ma50_short 10
# GC ma50_short 20
# GC ma100_long 1
# GC ma100_long 5
# GC ma100_long 10
# GC ma100_long 20
# GC ma100_short 1
# GC ma100_short 5
# GC ma100_short 10
# GC ma100_short 20
# GC bb_long 1
# GC bb_long 5
# GC bb_long 10
# GC bb_long 20
# GC bb_short 1
# GC bb_short 5
# GC bb_short 10
# GC bb_short 20
# SI vol_bo_long 1
# SI vol_bo_long 5
# SI vol_bo_long 10
# SI vol_bo_long 20
# SI vol_bo_short 1
# SI vol_bo_short 5
# SI vol_bo_short 10
# SI vol_bo_short 20
# SI range_bo_long 1
# SI range_bo_long 5
# SI range_bo_long 10
# SI range_bo_long 20
# SI range_bo_short 1
# SI range_bo_short 5
# SI range_bo_short 10
# SI range_bo_short 20
# SI ma20_long 1
# SI ma20_long 5
# SI ma20_long 10
# SI ma20_long 20
# SI ma20_short 1
# SI ma20_short 5
# SI ma20_short 10
# SI ma20_short 20
# SI ma50_long 1
# SI ma50_long 5
# SI ma50_long 10
# SI ma50_long 20
# SI ma50_short 1
# SI ma50_short 5
# SI ma50_short 10
# SI ma50_short 20
# SI ma100_long 1
# SI ma100_long 5
# SI ma100_long 10
# SI ma100_long 20
# SI ma100_short 1
# SI ma100_short 5
# SI ma100_short 10
# SI ma100_short 20
# SI bb_long 1
# SI bb_long 5
# SI bb_long 10
# SI bb_long 20
# SI bb_short 1
# SI bb_short 5
# SI bb_short 10
# SI bb_short 20
# AD vol_bo_long 1
# AD vol_bo_long 5
# AD vol_bo_long 10
# AD vol_bo_long 20
# AD vol_bo_short 1
# AD vol_bo_short 5
# AD vol_bo_short 10
# AD vol_bo_short 20
# AD range_bo_long 1
# AD range_bo_long 5
# AD range_bo_long 10
# AD range_bo_long 20
# AD range_bo_short 1
# AD range_bo_short 5
# AD range_bo_short 10
# AD range_bo_short 20
# AD ma20_long 1
# AD ma20_long 5
# AD ma20_long 10
# AD ma20_long 20
# AD ma20_short 1
# AD ma20_short 5
# AD ma20_short 10
# AD ma20_short 20
# AD ma50_long 1
# AD ma50_long 5
# AD ma50_long 10
# AD ma50_long 20
# AD ma50_short 1
# AD ma50_short 5
# AD ma50_short 10
# AD ma50_short 20
# AD ma100_long 1
# AD ma100_long 5
# AD ma100_long 10
# AD ma100_long 20
# AD ma100_short 1
# AD ma100_short 5
# AD ma100_short 10
# AD ma100_short 20
# AD bb_long 1
# AD bb_long 5
# AD bb_long 10
# AD bb_long 20
# AD bb_short 1
# AD bb_short 5
# AD bb_short 10
# AD bb_short 20
# CD vol_bo_long 1
# CD vol_bo_long 5
# CD vol_bo_long 10
# CD vol_bo_long 20
# CD vol_bo_short 1
# CD vol_bo_short 5
# CD vol_bo_short 10
# CD vol_bo_short 20
# CD range_bo_long 1
# CD range_bo_long 5
# CD range_bo_long 10
# CD range_bo_long 20
# CD range_bo_short 1
# CD range_bo_short 5
# CD range_bo_short 10
# CD range_bo_short 20
# CD ma20_long 1
# CD ma20_long 5
# CD ma20_long 10
# CD ma20_long 20
# CD ma20_short 1
# CD ma20_short 5
# CD ma20_short 10
# CD ma20_short 20
# CD ma50_long 1
# CD ma50_long 5
# CD ma50_long 10
# CD ma50_long 20
# CD ma50_short 1
# CD ma50_short 5
# CD ma50_short 10
# CD ma50_short 20
# CD ma100_long 1
# CD ma100_long 5
# CD ma100_long 10
# CD ma100_long 20
# CD ma100_short 1
# CD ma100_short 5
# CD ma100_short 10
# CD ma100_short 20
# CD bb_long 1
# CD bb_long 5
# CD bb_long 10
# CD bb_long 20
# CD bb_short 1
# CD bb_short 5
# CD bb_short 10
# CD bb_short 20
# EC vol_bo_long 1
# EC vol_bo_long 5
# EC vol_bo_long 10
# EC vol_bo_long 20
# EC vol_bo_short 1
# EC vol_bo_short 5
# EC vol_bo_short 10
# EC vol_bo_short 20
# EC range_bo_long 1
# EC range_bo_long 5
# EC range_bo_long 10
# EC range_bo_long 20
# EC range_bo_short 1
# EC range_bo_short 5
# EC range_bo_short 10
# EC range_bo_short 20
# EC ma20_long 1
# EC ma20_long 5
# EC ma20_long 10
# EC ma20_long 20
# EC ma20_short 1
# EC ma20_short 5
# EC ma20_short 10
# EC ma20_short 20
# EC ma50_long 1
# EC ma50_long 5
# EC ma50_long 10
# EC ma50_long 20
# EC ma50_short 1
# EC ma50_short 5
# EC ma50_short 10
# EC ma50_short 20
# EC ma100_long 1
# EC ma100_long 5
# EC ma100_long 10
# EC ma100_long 20
# EC ma100_short 1
# EC ma100_short 5
# EC ma100_short 10
# EC ma100_short 20
# EC bb_long 1
# EC bb_long 5
# EC bb_long 10
# EC bb_long 20
# EC bb_short 1
# EC bb_short 5
# EC bb_short 10
# EC bb_short 20
# BP vol_bo_long 1
# BP vol_bo_long 5
# BP vol_bo_long 10
# BP vol_bo_long 20
# BP vol_bo_short 1
# BP vol_bo_short 5
# BP vol_bo_short 10
# BP vol_bo_short 20
# BP range_bo_long 1
# BP range_bo_long 5
# BP range_bo_long 10
# BP range_bo_long 20
# BP range_bo_short 1
# BP range_bo_short 5
# BP range_bo_short 10
# BP range_bo_short 20
# BP ma20_long 1
# BP ma20_long 5
# BP ma20_long 10
# BP ma20_long 20
# BP ma20_short 1
# BP ma20_short 5
# BP ma20_short 10
# BP ma20_short 20
# BP ma50_long 1
# BP ma50_long 5
# BP ma50_long 10
# BP ma50_long 20
# BP ma50_short 1
# BP ma50_short 5
# BP ma50_short 10
# BP ma50_short 20
# BP ma100_long 1
# BP ma100_long 5
# BP ma100_long 10
# BP ma100_long 20
# BP ma100_short 1
# BP ma100_short 5
# BP ma100_short 10
# BP ma100_short 20
# BP bb_long 1
# BP bb_long 5
# BP bb_long 10
# BP bb_long 20
# BP bb_short 1
# BP bb_short 5
# BP bb_short 10
# BP bb_short 20
# JY vol_bo_long 1
# JY vol_bo_long 5
# JY vol_bo_long 10
# JY vol_bo_long 20
# JY vol_bo_short 1
# JY vol_bo_short 5
# JY vol_bo_short 10
# JY vol_bo_short 20
# JY range_bo_long 1
# JY range_bo_long 5
# JY range_bo_long 10
# JY range_bo_long 20
# JY range_bo_short 1
# JY range_bo_short 5
# JY range_bo_short 10
# JY range_bo_short 20
# JY ma20_long 1
# JY ma20_long 5
# JY ma20_long 10
# JY ma20_long 20
# JY ma20_short 1
# JY ma20_short 5
# JY ma20_short 10
# JY ma20_short 20
# JY ma50_long 1
# JY ma50_long 5
# JY ma50_long 10
# JY ma50_long 20
# JY ma50_short 1
# JY ma50_short 5
# JY ma50_short 10
# JY ma50_short 20
# JY ma100_long 1
# JY ma100_long 5
# JY ma100_long 10
# JY ma100_long 20
# JY ma100_short 1
# JY ma100_short 5
# JY ma100_short 10
# JY ma100_short 20
# JY bb_long 1
# JY bb_long 5
# JY bb_long 10
# JY bb_long 20
# JY bb_short 1
# JY bb_short 5
# JY bb_short 10
# JY bb_short 20
# US vol_bo_long 1
# US vol_bo_long 5
# US vol_bo_long 10
# US vol_bo_long 20
# US vol_bo_short 1
# US vol_bo_short 5
# US vol_bo_short 10
# US vol_bo_short 20
# US range_bo_long 1
# US range_bo_long 5
# US range_bo_long 10
# US range_bo_long 20
# US range_bo_short 1
# US range_bo_short 5
# US range_bo_short 10
# US range_bo_short 20
# US ma20_long 1
# US ma20_long 5
# US ma20_long 10
# US ma20_long 20
# US ma20_short 1
# US ma20_short 5
# US ma20_short 10
# US ma20_short 20
# US ma50_long 1
# US ma50_long 5
# US ma50_long 10
# US ma50_long 20
# US ma50_short 1
# US ma50_short 5
# US ma50_short 10
# US ma50_short 20
# US ma100_long 1
# US ma100_long 5
# US ma100_long 10
# US ma100_long 20
# US ma100_short 1
# US ma100_short 5
# US ma100_short 10
# US ma100_short 20
# US bb_long 1
# US bb_long 5
# US bb_long 10
# US bb_long 20
# US bb_short 1
# US bb_short 5
# US bb_short 10
# US bb_short 20
# C vol_bo_long 1
# C vol_bo_long 5
# C vol_bo_long 10
# C vol_bo_long 20
# C vol_bo_short 1
# C vol_bo_short 5
# C vol_bo_short 10
# C vol_bo_short 20
# C range_bo_long 1
# C range_bo_long 5
# C range_bo_long 10
# C range_bo_long 20
# C range_bo_short 1
# C range_bo_short 5
# C range_bo_short 10
# C range_bo_short 20
# C ma20_long 1
# C ma20_long 5
# C ma20_long 10
# C ma20_long 20
# C ma20_short 1
# C ma20_short 5
# C ma20_short 10
# C ma20_short 20
# C ma50_long 1
# C ma50_long 5
# C ma50_long 10
# C ma50_long 20
# C ma50_short 1
# C ma50_short 5
# C ma50_short 10
# C ma50_short 20
# C ma100_long 1
# C ma100_long 5
# C ma100_long 10
# C ma100_long 20
# C ma100_short 1
# C ma100_short 5
# C ma100_short 10
# C ma100_short 20
# C bb_long 1
# C bb_long 5
# C bb_long 10
# C bb_long 20
# C bb_short 1
# C bb_short 5
# C bb_short 10
# C bb_short 20
# W vol_bo_long 1
# W vol_bo_long 5
# W vol_bo_long 10
# W vol_bo_long 20
# W vol_bo_short 1
# W vol_bo_short 5
# W vol_bo_short 10
# W vol_bo_short 20
# W range_bo_long 1
# W range_bo_long 5
# W range_bo_long 10
# W range_bo_long 20
# W range_bo_short 1
# W range_bo_short 5
# W range_bo_short 10
# W range_bo_short 20
# W ma20_long 1
# W ma20_long 5
# W ma20_long 10
# W ma20_long 20
# W ma20_short 1
# W ma20_short 5
# W ma20_short 10
# W ma20_short 20
# W ma50_long 1
# W ma50_long 5
# W ma50_long 10
# W ma50_long 20
# W ma50_short 1
# W ma50_short 5
# W ma50_short 10
# W ma50_short 20
# W ma100_long 1
# W ma100_long 5
# W ma100_long 10
# W ma100_long 20
# W ma100_short 1
# W ma100_short 5
# W ma100_short 10
# W ma100_short 20
# W bb_long 1
# W bb_long 5
# W bb_long 10
# W bb_long 20
# W bb_short 1
# W bb_short 5
# W bb_short 10
# W bb_short 20
# S vol_bo_long 1
# S vol_bo_long 5
# S vol_bo_long 10
# S vol_bo_long 20
# S vol_bo_short 1
# S vol_bo_short 5
# S vol_bo_short 10
# S vol_bo_short 20
# S range_bo_long 1
# S range_bo_long 5
# S range_bo_long 10
# S range_bo_long 20
# S range_bo_short 1
# S range_bo_short 5
# S range_bo_short 10
# S range_bo_short 20
# S ma20_long 1
# S ma20_long 5
# S ma20_long 10
# S ma20_long 20
# S ma20_short 1
# S ma20_short 5
# S ma20_short 10
# S ma20_short 20
# S ma50_long 1
# S ma50_long 5
# S ma50_long 10
# S ma50_long 20
# S ma50_short 1
# S ma50_short 5
# S ma50_short 10
# S ma50_short 20
# S ma100_long 1
# S ma100_long 5
# S ma100_long 10
# S ma100_long 20
# S ma100_short 1
# S ma100_short 5
# S ma100_short 10
# S ma100_short 20
# S bb_long 1
# S bb_long 5
# S bb_long 10
# S bb_long 20
# S bb_short 1
# S bb_short 5
# S bb_short 10
# S bb_short 20
# ES vol_bo_long 1
# ES vol_bo_long 5
# ES vol_bo_long 10
# ES vol_bo_long 20
# ES vol_bo_short 1
# ES vol_bo_short 5
# ES vol_bo_short 10
# ES vol_bo_short 20
# ES range_bo_long 1
# ES range_bo_long 5
# ES range_bo_long 10
# ES range_bo_long 20
# ES range_bo_short 1
# ES range_bo_short 5
# ES range_bo_short 10
# ES range_bo_short 20
# ES ma20_long 1
# ES ma20_long 5
# ES ma20_long 10
# ES ma20_long 20
# ES ma20_short 1
# ES ma20_short 5
# ES ma20_short 10
# ES ma20_short 20
# ES ma50_long 1
# ES ma50_long 5
# ES ma50_long 10
# ES ma50_long 20
# ES ma50_short 1
# ES ma50_short 5
# ES ma50_short 10
# ES ma50_short 20
# ES ma100_long 1
# ES ma100_long 5
# ES ma100_long 10
# ES ma100_long 20
# ES ma100_short 1
# ES ma100_short 5
# ES ma100_short 10
# ES ma100_short 20
# ES bb_long 1
# ES bb_long 5
# ES bb_long 10
# ES bb_long 20
# ES bb_short 1
# ES bb_short 5
# ES bb_short 10
# ES bb_short 20
# BTC vol_bo_long 1
# BTC vol_bo_long 5
# BTC vol_bo_long 10
# BTC vol_bo_long 20
# BTC vol_bo_short 1
# BTC vol_bo_short 5
# BTC vol_bo_short 10
# BTC vol_bo_short 20
# BTC range_bo_long 1
# BTC range_bo_long 5
# BTC range_bo_long 10
# BTC range_bo_long 20
# BTC range_bo_short 1
# BTC range_bo_short 5
# BTC range_bo_short 10
# BTC range_bo_short 20
# BTC ma20_long 1
# BTC ma20_long 5
# BTC ma20_long 10
# BTC ma20_long 20
# BTC ma20_short 1
# BTC ma20_short 5
# BTC ma20_short 10
# BTC ma20_short 20
# BTC ma50_long 1
# BTC ma50_long 5
# BTC ma50_long 10
# BTC ma50_long 20
# BTC ma50_short 1
# BTC ma50_short 5
# BTC ma50_short 10
# BTC ma50_short 20
# BTC ma100_long 1
# BTC ma100_long 5
# BTC ma100_long 10
# BTC ma100_long 20
# BTC ma100_short 1
# BTC ma100_short 5
# BTC ma100_short 10
# BTC ma100_short 20
# BTC bb_long 1
# BTC bb_long 5
# BTC bb_long 10
# BTC bb_long 20
# BTC bb_short 1
# BTC bb_short 5
# BTC bb_short 10
# BTC bb_short 20
# ETH vol_bo_long 1
# ETH vol_bo_long 5
# ETH vol_bo_long 10
# ETH vol_bo_long 20
# ETH vol_bo_short 1
# ETH vol_bo_short 5
# ETH vol_bo_short 10
# ETH vol_bo_short 20
# ETH range_bo_long 1
# ETH range_bo_long 5
# ETH range_bo_long 10
# ETH range_bo_long 20
# ETH range_bo_short 1
# ETH range_bo_short 5
# ETH range_bo_short 10
# ETH range_bo_short 20
# ETH ma20_long 1
# ETH ma20_long 5
# ETH ma20_long 10
# ETH ma20_long 20
# ETH ma20_short 1
# ETH ma20_short 5
# ETH ma20_short 10
# ETH ma20_short 20
# ETH ma50_long 1
# ETH ma50_long 5
# ETH ma50_long 10
# ETH ma50_long 20
# ETH ma50_short 1
# ETH ma50_short 5
# ETH ma50_short 10
# ETH ma50_short 20
# ETH ma100_long 1
# ETH ma100_long 5
# ETH ma100_long 10
# ETH ma100_long 20
# ETH ma100_short 1
# ETH ma100_short 5
# ETH ma100_short 10
# ETH ma100_short 20
# ETH bb_long 1
# ETH bb_long 5
# ETH bb_long 10
# ETH bb_long 20
# ETH bb_short 1
# ETH bb_short 5
# ETH bb_short 10
# ETH bb_short 20
# XRP vol_bo_long 1
# XRP vol_bo_long 5
# XRP vol_bo_long 10
# XRP vol_bo_long 20
# XRP vol_bo_short 1
# XRP vol_bo_short 5
# XRP vol_bo_short 10
# XRP vol_bo_short 20
# XRP range_bo_long 1
# XRP range_bo_long 5
# XRP range_bo_long 10
# XRP range_bo_long 20
# XRP range_bo_short 1
# XRP range_bo_short 5
# XRP range_bo_short 10
# XRP range_bo_short 20
# XRP ma20_long 1
# XRP ma20_long 5
# XRP ma20_long 10
# XRP ma20_long 20
# XRP ma20_short 1
# XRP ma20_short 5
# XRP ma20_short 10
# XRP ma20_short 20
# XRP ma50_long 1
# XRP ma50_long 5
# XRP ma50_long 10
# XRP ma50_long 20
# XRP ma50_short 1
# XRP ma50_short 5
# XRP ma50_short 10
# XRP ma50_short 20
# XRP ma100_long 1
# XRP ma100_long 5
# XRP ma100_long 10
# XRP ma100_long 20
# XRP ma100_short 1
# XRP ma100_short 5
# XRP ma100_short 10
# XRP ma100_short 20
# XRP bb_long 1
# XRP bb_long 5
# XRP bb_long 10
# XRP bb_long 20
# XRP bb_short 1
# XRP bb_short 5
# XRP bb_short 10
# XRP bb_short 20
# LTC vol_bo_long 1
# LTC vol_bo_long 5
# LTC vol_bo_long 10
# LTC vol_bo_long 20
# LTC vol_bo_short 1
# LTC vol_bo_short 5
# LTC vol_bo_short 10
# LTC vol_bo_short 20
# LTC range_bo_long 1
# LTC range_bo_long 5
# LTC range_bo_long 10
# LTC range_bo_long 20
# LTC range_bo_short 1
# LTC range_bo_short 5
# LTC range_bo_short 10
# LTC range_bo_short 20
# LTC ma20_long 1
# LTC ma20_long 5
# LTC ma20_long 10
# LTC ma20_long 20
# LTC ma20_short 1
# LTC ma20_short 5
# LTC ma20_short 10
# LTC ma20_short 20
# LTC ma50_long 1
# LTC ma50_long 5
# LTC ma50_long 10
# LTC ma50_long 20
# LTC ma50_short 1
# LTC ma50_short 5
# LTC ma50_short 10
# LTC ma50_short 20
# LTC ma100_long 1
# LTC ma100_long 5
# LTC ma100_long 10
# LTC ma100_long 20
# LTC ma100_short 1
# LTC ma100_short 5
# LTC ma100_short 10
# LTC ma100_short 20
# LTC bb_long 1
# LTC bb_long 5
# LTC bb_long 10
# LTC bb_long 20
# LTC bb_short 1
# LTC bb_short 5
# LTC bb_short 10
# LTC bb_short 20
# XLM vol_bo_long 1
# XLM vol_bo_long 5
# XLM vol_bo_long 10
# XLM vol_bo_long 20
# XLM vol_bo_short 1
# XLM vol_bo_short 5
# XLM vol_bo_short 10
# XLM vol_bo_short 20
# XLM range_bo_long 1
# XLM range_bo_long 5
# XLM range_bo_long 10
# XLM range_bo_long 20
# XLM range_bo_short 1
# XLM range_bo_short 5
# XLM range_bo_short 10
# XLM range_bo_short 20
# XLM ma20_long 1
# XLM ma20_long 5
# XLM ma20_long 10
# XLM ma20_long 20
# XLM ma20_short 1
# XLM ma20_short 5
# XLM ma20_short 10
# XLM ma20_short 20
# XLM ma50_long 1
# XLM ma50_long 5
# XLM ma50_long 10
# XLM ma50_long 20
# XLM ma50_short 1
# XLM ma50_short 5
# XLM ma50_short 10
# XLM ma50_short 20
# XLM ma100_long 1
# XLM ma100_long 5
# XLM ma100_long 10
# XLM ma100_long 20
# XLM ma100_short 1
# XLM ma100_short 5
# XLM ma100_short 10
# XLM ma100_short 20
# XLM bb_long 1
# XLM bb_long 5
# XLM bb_long 10
# XLM bb_long 20
# XLM bb_short 1
# XLM bb_short 5
# XLM bb_short 10
# XLM bb_short 20
# EOS vol_bo_long 1
# EOS vol_bo_long 5
# EOS vol_bo_long 10
# EOS vol_bo_long 20
# EOS vol_bo_short 1
# EOS vol_bo_short 5
# EOS vol_bo_short 10
# EOS vol_bo_short 20
# EOS range_bo_long 1
# EOS range_bo_long 5
# EOS range_bo_long 10
# EOS range_bo_long 20
# EOS range_bo_short 1
# EOS range_bo_short 5
# EOS range_bo_short 10
# EOS range_bo_short 20
# EOS ma20_long 1
# EOS ma20_long 5
# EOS ma20_long 10
# EOS ma20_long 20
# EOS ma20_short 1
# EOS ma20_short 5
# EOS ma20_short 10
# EOS ma20_short 20
# EOS ma50_long 1
# EOS ma50_long 5
# EOS ma50_long 10
# EOS ma50_long 20
# EOS ma50_short 1
# EOS ma50_short 5
# EOS ma50_short 10
# EOS ma50_short 20
# EOS ma100_long 1
# EOS ma100_long 5
# EOS ma100_long 10
# EOS ma100_long 20
# EOS ma100_short 1
# EOS ma100_short 5
# EOS ma100_short 10
# EOS ma100_short 20
# EOS bb_long 1
# EOS bb_long 5
# EOS bb_long 10
# EOS bb_long 20
# EOS bb_short 1
# EOS bb_short 5
# EOS bb_short 10
# EOS bb_short 20
# NEO vol_bo_long 1
# NEO vol_bo_long 5
# NEO vol_bo_long 10
# NEO vol_bo_long 20
# NEO vol_bo_short 1
# NEO vol_bo_short 5
# NEO vol_bo_short 10
# NEO vol_bo_short 20
# NEO range_bo_long 1
# NEO range_bo_long 5
# NEO range_bo_long 10
# NEO range_bo_long 20
# NEO range_bo_short 1
# NEO range_bo_short 5
# NEO range_bo_short 10
# NEO range_bo_short 20
# NEO ma20_long 1
# NEO ma20_long 5
# NEO ma20_long 10
# NEO ma20_long 20
# NEO ma20_short 1
# NEO ma20_short 5
# NEO ma20_short 10
# NEO ma20_short 20
# NEO ma50_long 1
# NEO ma50_long 5
# NEO ma50_long 10
# NEO ma50_long 20
# NEO ma50_short 1
# NEO ma50_short 5
# NEO ma50_short 10
# NEO ma50_short 20
# NEO ma100_long 1
# NEO ma100_long 5
# NEO ma100_long 10
# NEO ma100_long 20
# NEO ma100_short 1
# NEO ma100_short 5
# NEO ma100_short 10
# NEO ma100_short 20
# NEO bb_long 1
# NEO bb_long 5
# NEO bb_long 10
# NEO bb_long 20
# NEO bb_short 1
# NEO bb_short 5
# NEO bb_short 10
# NEO bb_short 20
# ADA vol_bo_long 1
# ADA vol_bo_long 5
# ADA vol_bo_long 10
# ADA vol_bo_long 20
# ADA vol_bo_short 1
# ADA vol_bo_short 5
# ADA vol_bo_short 10
# ADA vol_bo_short 20
# ADA range_bo_long 1
# ADA range_bo_long 5
# ADA range_bo_long 10
# ADA range_bo_long 20
# ADA range_bo_short 1
# ADA range_bo_short 5
# ADA range_bo_short 10
# ADA range_bo_short 20
# ADA ma20_long 1
# ADA ma20_long 5
# ADA ma20_long 10
# ADA ma20_long 20
# ADA ma20_short 1
# ADA ma20_short 5
# ADA ma20_short 10
# ADA ma20_short 20
# ADA ma50_long 1
# ADA ma50_long 5
# ADA ma50_long 10
# ADA ma50_long 20
# ADA ma50_short 1
# ADA ma50_short 5
# ADA ma50_short 10
# ADA ma50_short 20
# ADA ma100_long 1
# ADA ma100_long 5
# ADA ma100_long 10
# ADA ma100_long 20
# ADA ma100_short 1
# ADA ma100_short 5
# ADA ma100_short 10
# ADA ma100_short 20
# ADA bb_long 1
# ADA bb_long 5
# ADA bb_long 10
# ADA bb_long 20
# ADA bb_short 1
# ADA bb_short 5
# ADA bb_short 10
# ADA bb_short 20
# BCH vol_bo_long 1
# BCH vol_bo_long 5
# BCH vol_bo_long 10
# BCH vol_bo_long 20
# BCH vol_bo_short 1
# BCH vol_bo_short 5
# BCH vol_bo_short 10
# BCH vol_bo_short 20
# BCH range_bo_long 1
# BCH range_bo_long 5
# BCH range_bo_long 10
# BCH range_bo_long 20
# BCH range_bo_short 1
# BCH range_bo_short 5
# BCH range_bo_short 10
# BCH range_bo_short 20
# BCH ma20_long 1
# BCH ma20_long 5
# BCH ma20_long 10
# BCH ma20_long 20
# BCH ma20_short 1
# BCH ma20_short 5
# BCH ma20_short 10
# BCH ma20_short 20
# BCH ma50_long 1
# BCH ma50_long 5
# BCH ma50_long 10
# BCH ma50_long 20
# BCH ma50_short 1
# BCH ma50_short 5
# BCH ma50_short 10
# BCH ma50_short 20
# BCH ma100_long 1
# BCH ma100_long 5
# BCH ma100_long 10
# BCH ma100_long 20
# BCH ma100_short 1
# BCH ma100_short 5
# BCH ma100_short 10
# BCH ma100_short 20
# BCH bb_long 1
# BCH bb_long 5
# BCH bb_long 10
# BCH bb_long 20
# BCH bb_short 1
# BCH bb_short 5
# BCH bb_short 10
# BCH bb_short 20
# XMR vol_bo_long 1
# XMR vol_bo_long 5
# XMR vol_bo_long 10
# XMR vol_bo_long 20
# XMR vol_bo_short 1
# XMR vol_bo_short 5
# XMR vol_bo_short 10
# XMR vol_bo_short 20
# XMR range_bo_long 1
# XMR range_bo_long 5
# XMR range_bo_long 10
# XMR range_bo_long 20
# XMR range_bo_short 1
# XMR range_bo_short 5
# XMR range_bo_short 10
# XMR range_bo_short 20
# XMR ma20_long 1
# XMR ma20_long 5
# XMR ma20_long 10
# XMR ma20_long 20
# XMR ma20_short 1
# XMR ma20_short 5
# XMR ma20_short 10
# XMR ma20_short 20
# XMR ma50_long 1
# XMR ma50_long 5
# XMR ma50_long 10
# XMR ma50_long 20
# XMR ma50_short 1
# XMR ma50_short 5
# XMR ma50_short 10
# XMR ma50_short 20
# XMR ma100_long 1
# XMR ma100_long 5
# XMR ma100_long 10
# XMR ma100_long 20
# XMR ma100_short 1
# XMR ma100_short 5
# XMR ma100_short 10
# XMR ma100_short 20
# XMR bb_long 1
# XMR bb_long 5
# XMR bb_long 10
# XMR bb_long 20
# XMR bb_short 1
# XMR bb_short 5
# XMR bb_short 10
# XMR bb_short 20

# %% [markdown]
# We will print out the info on our new dataframe in order to check that things look good.

# %%
returns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
# product            1200 non-null object
# signal             1200 non-null object
# timeframe          1200 non-null object
# signal_count       1200 non-null object
# signals_per_day    1200 non-null float64
# ave_return         1172 non-null float64
# std_return         1152 non-null float64
# min_return         1172 non-null float64
# max_return         1172 non-null float64
# q25_return         1172 non-null float64
# q75_return         1172 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 112.5+ KB

# %% [markdown]
# It looks like we got through all iterations as we expected to see **1,200 total rows**, for our **25 products**, **12 signals**, and **4 timeframes**.
#
# We do have some null values that we want to investigate.

# %%
returns_df[returns_df.std_return.isnull()]
# Out:
#      product         signal timeframe signal_count  signals_per_day  \
# 0         CL    vol_bo_long         1            1         0.000397
# 1         CL    vol_bo_long         5            1         0.000397
# 2         CL    vol_bo_long        10            1         0.000397
# 3         CL    vol_bo_long        20            1         0.000397
# 48        HO    vol_bo_long         1            1         0.000396
# 49        HO    vol_bo_long         5            1         0.000396
# 50        HO    vol_bo_long        10            1         0.000396
# 51        HO    vol_bo_long        20            1         0.000396
# 52        HO   vol_bo_short         1            1         0.000396
# 53        HO   vol_bo_short         5            1         0.000396
# 54        HO   vol_bo_short        10            1         0.000396
# 55        HO   vol_bo_short        20            1         0.000396
# 100       NG   vol_bo_short         1            0         0.000000
# 101       NG   vol_bo_short         5            0         0.000000
# 102       NG   vol_bo_short        10            0         0.000000
# 103       NG   vol_bo_short        20            0         0.000000
# 1056     ADA    vol_bo_long         1            1         0.010638
# 1057     ADA    vol_bo_long         5            1         0.010638
# 1058     ADA    vol_bo_long        10            1         0.010638
# 1059     ADA    vol_bo_long        20            1         0.010638
# 1060     ADA   vol_bo_short         1            0         0.000000
# 1061     ADA   vol_bo_short         5            0         0.000000
# 1062     ADA   vol_bo_short        10            0         0.000000
# 1063     ADA   vol_bo_short        20            0         0.000000
# 1064     ADA  range_bo_long         1            0         0.000000
# 1065     ADA  range_bo_long         5            0         0.000000
# 1066     ADA  range_bo_long        10            0         0.000000
# 1067     ADA  range_bo_long        20            0         0.000000
# 1072     ADA      ma20_long         1            1         0.010638
# 1073     ADA      ma20_long         5            1         0.010638
# 1074     ADA      ma20_long        10            1         0.010638
# 1075     ADA      ma20_long        20            1         0.010638
# 1080     ADA      ma50_long         1            0         0.000000
# 1081     ADA      ma50_long         5            0         0.000000
# 1082     ADA      ma50_long        10            0         0.000000
# 1083     ADA      ma50_long        20            0         0.000000
# 1088     ADA     ma100_long         1            0         0.000000
# 1089     ADA     ma100_long         5            0         0.000000
# 1090     ADA     ma100_long        10            0         0.000000
# 1091     ADA     ma100_long        20            0         0.000000
# 1092     ADA    ma100_short         1            0         0.000000
# 1093     ADA    ma100_short         5            0         0.000000
# 1094     ADA    ma100_short        10            0         0.000000
# 1095     ADA    ma100_short        20            0         0.000000
# 1100     ADA       bb_short         1            0         0.000000
# 1101     ADA       bb_short         5            0         0.000000
# 1102     ADA       bb_short        10            0         0.000000
# 1103     ADA       bb_short        20            0         0.000000
#
#       ave_return  std_return  min_return  max_return  q25_return  q75_return
# 0       0.039823         NaN    0.039823    0.039823    0.039823    0.039823
# 1      -0.018215         NaN   -0.018215   -0.018215   -0.018215   -0.018215
# 2      -0.000068         NaN   -0.000068   -0.000068   -0.000068   -0.000068
# 3       0.067599         NaN    0.067599    0.067599    0.067599    0.067599
# 48      0.003687         NaN    0.003687    0.003687    0.003687    0.003687
# 49      0.100618         NaN    0.100618    0.100618    0.100618    0.100618
# 50      0.142194         NaN    0.142194    0.142194    0.142194    0.142194
# 51      0.146510         NaN    0.146510    0.146510    0.146510    0.146510
# 52      0.014271         NaN   -0.014271   -0.014271   -0.014271   -0.014271
# 53      0.130234         NaN   -0.130234   -0.130234   -0.130234   -0.130234
# 54      0.110496         NaN   -0.110496   -0.110496   -0.110496   -0.110496
# 55      0.112383         NaN   -0.112383   -0.112383   -0.112383   -0.112383
# 100          NaN         NaN         NaN         NaN         NaN         NaN
# 101          NaN         NaN         NaN         NaN         NaN         NaN
# 102          NaN         NaN         NaN         NaN         NaN         NaN
# 103          NaN         NaN         NaN         NaN         NaN         NaN
# 1056    0.225806         NaN    0.225806    0.225806    0.225806    0.225806
# 1057   -0.017072         NaN   -0.017072   -0.017072   -0.017072   -0.017072
# 1058   -0.119147         NaN   -0.119147   -0.119147   -0.119147   -0.119147
# 1059   -0.420732         NaN   -0.420732   -0.420732   -0.420732   -0.420732
# 1060         NaN         NaN         NaN         NaN         NaN         NaN
# 1061         NaN         NaN         NaN         NaN         NaN         NaN
# 1062         NaN         NaN         NaN         NaN         NaN         NaN
# 1063         NaN         NaN         NaN         NaN         NaN         NaN
# 1064         NaN         NaN         NaN         NaN         NaN         NaN
# 1065         NaN         NaN         NaN         NaN         NaN         NaN
# 1066         NaN         NaN         NaN         NaN         NaN         NaN
# 1067         NaN         NaN         NaN         NaN         NaN         NaN
# 1072    0.051282         NaN    0.051282    0.051282    0.051282    0.051282
# 1073    0.105121         NaN    0.105121    0.105121    0.105121    0.105121
# 1074    0.238671         NaN    0.238671    0.238671    0.238671    0.238671
# 1075   -0.361669         NaN   -0.361669   -0.361669   -0.361669   -0.361669
# 1080         NaN         NaN         NaN         NaN         NaN         NaN
# 1081         NaN         NaN         NaN         NaN         NaN         NaN
# 1082         NaN         NaN         NaN         NaN         NaN         NaN
# 1083         NaN         NaN         NaN         NaN         NaN         NaN
# 1088         NaN         NaN         NaN         NaN         NaN         NaN
# 1089         NaN         NaN         NaN         NaN         NaN         NaN
# 1090         NaN         NaN         NaN         NaN         NaN         NaN
# 1091         NaN         NaN         NaN         NaN         NaN         NaN
# 1092         NaN         NaN         NaN         NaN         NaN         NaN
# 1093         NaN         NaN         NaN         NaN         NaN         NaN
# 1094         NaN         NaN         NaN         NaN         NaN         NaN
# 1095         NaN         NaN         NaN         NaN         NaN         NaN
# 1100         NaN         NaN         NaN         NaN         NaN         NaN
# 1101         NaN         NaN         NaN         NaN         NaN         NaN
# 1102         NaN         NaN         NaN         NaN         NaN         NaN
# 1103         NaN         NaN         NaN         NaN         NaN         NaN

# %% [markdown]
# There are two reasons for null values here, one is no signals for the given product/signal/timeframe combination.  The other is there only being 1 signal for the combination and therefore the standard deviation calculation is NaN, due to dividing by zero.
#
# In each case we can simply drop the columns without losing any significant information.

# %%
returns_df.dropna(inplace=True)
returns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1152 entries, 4 to 1199
# Data columns (total 11 columns):
# product            1152 non-null object
# signal             1152 non-null object
# timeframe          1152 non-null object
# signal_count       1152 non-null object
# signals_per_day    1152 non-null float64
# ave_return         1152 non-null float64
# std_return         1152 non-null float64
# min_return         1152 non-null float64
# max_return         1152 non-null float64
# q25_return         1152 non-null float64
# q75_return         1152 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 108.0+ KB

# %% [markdown]
# ## Initial Research Findings

# %% [markdown]
# Now that we have a dataframe of return data lets explore it visually to generate some insights about the ability to consistently predict future price movements.

# %% [markdown]
# First lets simply look at the distribution of **ave_return**.

# %%
from scipy.stats import norm

fig, ax = plt.subplots(figsize=(18,7))
ax = sns.distplot(returns_df.ave_return, fit=norm)

# %% [markdown]
# This distribution is clearly not normal, with most of the observations right around zero.  However it does appear that the mean is positive and the distribution is slightly skewed to the right.

# %%
print('Mean of ave_return: {}'.format(returns_df.ave_return.mean()))
print('Skewness of ave_return: {}'.format(returns_df.ave_return.skew()))
print('Kurtosis of ave_return: {}'.format(returns_df.ave_return.kurtosis()))
# Out:
# Mean of ave_return: 0.06252901917687709
# Skewness of ave_return: 1.9717318752205
# Kurtosis of ave_return: 26.266115705909876

# %% [markdown]
# This shows some promise that we have more winning strategies that losing ones and that hopefully the winners also have greater magnitude than the losers.
#
# Now lets look at the top and bottom 100 combinations sorted by **ave_return**.

# %%
# Index by product and signal then take the top and bottom 100 combinations
top100 = returns_df.set_index(['product', 'signal'], drop=True).sort_values(by='ave_return', ascending=False)[:100]
bottom100 = returns_df.set_index(['product', 'signal'], drop=True).sort_values(by='ave_return')[:100]

# %%
top100.head()
# Out:
#                       timeframe signal_count  signals_per_day  ave_return  \
# product signal
# XRP     range_bo_long        20           30         0.080000    2.677800
# XLM     vol_bo_long          20           16         0.048048    1.937158
# XRP     vol_bo_long          20           26         0.069333    1.916933
# XLM     range_bo_long        20           25         0.075075    1.678717
# EOS     range_bo_long        20           28         0.101818    1.609118
#
#                        std_return  min_return  max_return  q25_return  \
# product signal
# XRP     range_bo_long    2.865334    0.102477    9.644337    0.408359
# XLM     vol_bo_long      1.166752   -0.083631    3.762110    0.964861
# XRP     vol_bo_long      2.783252   -0.248175    9.644337    0.248019
# XLM     range_bo_long    1.216300    0.142410    3.762110    0.547138
# EOS     range_bo_long    0.869831    0.194982    3.361702    0.956639
#
#                        q75_return
# product signal
# XRP     range_bo_long    4.175874
# XLM     vol_bo_long      2.801516
# XRP     vol_bo_long      2.449687
# XLM     range_bo_long    2.789645
# EOS     range_bo_long    2.207234

# %%
bottom100.head()
# Out:
#                  timeframe signal_count  signals_per_day  ave_return  \
# product signal
# XRP     bb_short        20           57         0.152000   -1.911211
# XLM     bb_short        20           40         0.120120   -1.647313
# EOS     bb_short        20           39         0.141818   -1.571822
# BCH     bb_short        20           23         0.093878   -0.996021
# XRP     bb_short        10           57         0.152000   -0.975302
#
#                   std_return  min_return  max_return  q25_return  q75_return
# product signal
# XRP     bb_short    2.518295   -0.189655    9.644337    0.244444    2.700691
# XLM     bb_short    1.134437   -0.100822    3.762110    0.540705    2.448912
# EOS     bb_short    0.905577   -0.125765    3.361702    0.912399    2.238692
# BCH     bb_short    1.050740    0.011200    3.404390    0.255354    1.122374
# XRP     bb_short    0.968764    0.009256    3.569563    0.183473    1.784294

# %% [markdown]
# This is a snapshot of the top and bottom , lets look at a visualization and make some observations.

# %%
# Plot counts by product
fig, ax = plt.subplots(figsize=(18,7))

top100 = pd.DataFrame(top100.reset_index())
ax = sns.countplot(x='product', data=top100,
                   order=top100['product'].value_counts().index, palette=sns.color_palette('Blues_r', 10))
ax.set(title='Number of combinations in Top100\nby Product')
# Out:
# /Users/Frank/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# [Text(0.5,1,'Number of combinations in Top100\nby Product')]

# %%
# Plot counts by product
fig, ax = plt.subplots(figsize=(18,7))

bottom100 = bottom100.reset_index()
ax = sns.countplot(x='product', data=bottom100, 
                   order=bottom100['product'].value_counts().index, palette=sns.color_palette('Blues', 17))
# Out:
# /Users/Frank/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# It turns out that **XLM** is the product in the most top100 combinations as well as the bottom100.  We can also see that **Cryptocurrencies** are clearly the most volatile class, all 10 that we tracked showed up in the top100 combinations as well as the bottom100.
#
# In the bottom100 we see that all products from the **Grains** and **Energy** sectors made the list.

# %%
ax = sns.stripplot(x='signal', y='ave_return', data=returns_df)

# %%
g = sns.FacetGrid(returns_df[returns_df.signal_count > 100], row='signal', col='timeframe')
g.map(sns.distplot, "ave_return")

# %%
fig, ax = plt.subplots(figsize=(18,7))
df1 = returns_df.pivot_table(index='product', columns='signal', values='ave_return', aggfunc=np.mean)
sns.heatmap(df1, annot=True, fmt=".2%", ax=ax)

# %%
returns_df.reset_index(drop=True, inplace=True)
# Out:
#   product         signal timeframe signal_count  signals_per_day  ave_return  \
# 0      CL   vol_bo_short         1            4         0.001589    0.037496
# 1      CL   vol_bo_short         5            4         0.001589    0.055208
# 2      CL   vol_bo_short        10            4         0.001589    0.040678
# 3      CL   vol_bo_short        20            4         0.001589    0.013130
# 4      CL  range_bo_long         1          416         0.165276    0.011216
#
#    std_return  min_return  max_return  q25_return  q75_return
# 0    0.033766   -0.086415   -0.013273   -0.046645   -0.016001
# 1    0.042157   -0.115719   -0.019291   -0.065786   -0.032333
# 2    0.055094   -0.104531    0.013933   -0.076914    0.000179
# 3    0.102172   -0.116394    0.093332   -0.091329    0.063469
# 4    0.016088   -0.043735    0.089556    0.001289    0.019751

# %%
groupby_prod_sig = pd.DataFrame(returns_df.groupby(['product', 'signal'])['ave_return'].mean())
groupby_prod_sig.reset_index(inplace=True)
groupby_prod_sig.head()
# Out:
#   product       signal  ave_return
# 0      AD      bb_long   -0.023071
# 1      AD     bb_short   -0.019779
# 2      AD   ma100_long    0.008251
# 3      AD  ma100_short    0.010169
# 4      AD    ma20_long    0.013518
